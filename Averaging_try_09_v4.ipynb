# %% [markdown]
# # Facial Expression Recognition Tutorial

# %% [markdown]
# ## 1.1 Introduction
#
#
# ---
#
# > "My words always get me into troubles. And if not my words, it is my facial expressions."
# -- Manasa Rao
#
# ---
#
# <br>
#
# The ability to recognize facial expressions automatically enables novel applications in human-computer interaction
# and other areas including, but not limited to, human behavior understanding, detection of mental disorders, and synthetic human expressions. Consequently, there has been active research in this field, with several recent works utilizing Convolutional
# Neural Networks (**CNN**s) for feature extraction and inference.
#
# <br/>
# In this tutorial we implement and analye a **CNN** based model for recognising Facial Expressions. The model is largely based on this paper [Image based Static Facial Expression Recognition with Multiple Deep Network Learning](https://www.microsoft.com/en-us/research/wp-content/uploads/2016/02/icmi2015_ChaZhang.pdf). To further improve the accuacy, we will modify the model based on our learning from other papers.
#
# <br/>We have tried differnt apporaches in this paper and published the results for the user . We have also compared our results to the reported SOTA (state-of-the-art) metrics of Facial Expression Recognition test results. In the end we also suggest a few probable methods to further improve the accuracy.
#
# *Tony James*
# [@tonyissacjames](https://github.com/tonyissacjames)

# %% [markdown]
# ## 1.2 Objective of the tutorial
#
# Get  a score of 0.69 or more for this [Kaggle challenge](https://www.kaggle.com/c/challenges-in-representation-learning-facial-expression-recognition-challenge/leaderboard).<br/>
# The challenge is no longer active so we can use the same data set(**fer2013**) used for the Kaggle competition to train and evaluate our model.

# %% [markdown]
# ## 1.3 About the data set
#
# We are using **fer2013** dataset for training, validation and testing.
# <br/>This data set can be downloaded from this Kaggle challenge https://www.kaggle.com/c/challenges-in-representation-learning-facial-expression-recognition-challenge/leaderboard
# <br/>This data set has images of 7 different facial expressions expressing Anger, Disgust, Fear, Happy, Neutral, Sad, Suprise.
# <br/>
# <br/>
# This data set has there categories namely Training, PublicTest, PrivateTest. <br/>**Kaggle** has given the Training category for training the models and used PublicTest for their Public Leader Board evaluation. PrivateTest was not known to users until the challenge was closed and it was used for Private Leader Board evaluation. Once this Competition was closed, **Kaggle** released all there categories to public in **fer2013.csv** file.
# <br/>We will use Training category for Training, PublicTest for Validation and PrivateTest for Testing our model
#
#
# - Train: 32181 images
# - Validation: 3589 images
# - Test : 3589 images
# - Images are of resolution 48x48 and singel channel
# - Number of Classes: 7
#  - 0: Anger
#  - 1: Disgust
#  - 2: Fear
#  - 3: Happy
#  - 4: Neutral
#  - 5: Sad
#  - 6: Suprise
#
# <br/>
#
# - We have written few helper functions in **HelperDataProcessing** class to load and preprocess the data and also reshape the data to our needs, use them to save time and some trouble.
#  - The data provided in the **fer2013.csv** file is of list format, our helper functions can convert it to 48x48 numpy array format
#  - LamUong (https://github.com/LamUong/) have identifed some bad training data, and the helper funcions eliminate them while loading

# %% [markdown]
# ## 1.4 How do we proceed
#
# ### Follow the  Steps below
#
# 1. Read Zhiding Yu's & Cha Zhang's paper [1] [Image based Static Facial Expression Recognition with Multiple Deep Network Learning](https://www.microsoft.com/en-us/research/wp-content/uploads/2016/02/icmi2015_ChaZhang.pdf)
#     - **It is very important to understand this paper**
#     - We are going to implement the **CNN** model and methods in this paper
# <br/>
# <br/>
# 2. (**Optional**) Go through this repo - [https://github.com/LamUong/FacialExpressionRecognition](https://github.com/LamUong/FacialExpressionRecognition)
#     - it has lot of helper functions to read data
#     - It has code Simple Average Ensemble method
#     - We have build our helper functions using helper functions from this repo (this saved us lot of trouble and time()
# <br/>
# <br/>
# 3. Do Exploratory data analysis
#     - and build some intution about the data
#     - identify any possibble problem in the dataset and plan for mitigating them them
# <br/>
# <br/>
# 4. Build a NN model based on Zhiding Yu's paper [1]
#     - Use the basic **CNN** model given in the paper as a reference design
#     - Try to improve the model by
#        - adding more layers
#        - using different optimiser
#        - using different cost function etc.
#     - Use randomized peturbation of training data (Data Augmentation)
#        - The ensemble models use randomized peturbation to generate multiple outputs. So we can use same petrubations for training as well
#     - Get as high testing accuracy as possible
# <br/>
# <br/>
# 5. Evaluate the model's performance on Private Leader Board data
# <br/>
# <br/>
# 6. Analyse the results of the stand alone model
#     - print confusion matrix
#     - plot validation/training accuracy/loss
#     - decide what can be further done
# <br/>
# <br/>
# 7. Build Multiple Network Learning Models
#     - On top of **CNN** we have added a multiple network learning framework to ensemble multiple models. Different ensemble models can further increase performance. Two such models we have implemented are given below.
#         - **Simple Average Ensembling**
#             - here we give randomly perturbed version of the image to **CNN** network. Final ouput is the average of all the ouput of the **CNN** network.
#         - **Optimal Hinge Loss Ensembling**
#             - here we give randomly perturbed version of the image to **CNN** network. And all such ouputs are fed into another **NN** which is optimised for Hinge Loss. The **NN** calculates the final output.
#         - **Optimal Mean Squred Error(MSE) Ensembling**
#             - here we give randomly perturbed version of the image to **CNN** network. And all such ouputs are fed into another **NN** which is optimised for Mean Squred Error (MSE) Loss. The **NN** calculates the final output.
# <br/>
# <br/>
# 8. Compare the results of different approaches on Private Leader Board data
#     - Choose the one with highest tesing accuracy
#         - and hope it achieves 0.69 or more on **fer2013**
# <br/>
# <br/>
# 9. Write down the Conclusion
#     - compare the results with reported SOTA performance
#     - few probable methods to further improve the accuracy
#     - (**Optional**) few observations which might help the reader in the futrue

# %% [markdown]
# ## 1.5 References
# [1] [Image based Static Facial Expression Recognition with Multiple Deep Network Learning](https://www.microsoft.com/en-us/research/wp-content/uploads/2016/02/icmi2015_ChaZhang.pdf)
# <br/>
# [2] [Facial Emotion Recognition in Real Time](http://cs231n.stanford.edu/reports/2016/pdfs/022_Report.pdf)
# <br/>
# [3] [Facial Expression Recognition using Convolutional Neural Networks: State of the Art](https://arxiv.org/abs/1612.02903)
# <br/>
# [4] [Learning Social Relation Traits from Face Images](https://www.cv-foundation.org/openaccess/content_iccv_2015/papers/Zhang_Learning_Social_Relation_ICCV_2015_paper.pdf)
# <br/>
# [5] [Deep Learning using Linear Support Vector Machines](http://deeplearning.net/wp-content/uploads/2013/03/dlsvm.pdf)

# %% [markdown]
# ## 1.6 Results
# ### Accuracy of different approaches are given below
# 1. Stand-alone **CNN** model: **0.6937**
# 2. Multiple Network Learning Models - **CNN** with Simple Average Ensembling: **0.7015**
# 3. Multiple Network Learning Models - **CNN** with Hinge Loss Ensembling: **0.7068**
# 4. Multiple Network Learning Models - **CNN** with Mean Squred Error(MSE) Ensembling: **0.7088**
# <br/>
# <br/>
# Maximum achieved accuracy of our implementation for **fer2013** dataset:  **0.7088**

# %% [markdown]
# # 2 Summary of Conclusion
#
# Ususlly **Conclusion** comes at the end. But we have put a summary of Conclusion at the top so it can be looked up easily.
# <br/>
# <br/>
# - In this tutorial we have tried different **CNN** based approach for Facial Expression Recognition.<br>
# - It is observed that **Multiple Network Learning Models - CNN with Mean Squred Error(MSE) Ensembling** gives the maximum performace on **fer2013** data set.<br> **CNN with Mean Squred Error(MSE) Ensembling** gives an accuracy of **0.7088**. This supasses our intial expectation of **0.69**. <br>
# - So we have attained our objective.

# %% [markdown]
# ## 2.1 Comparing results
# - Maximum achieved accuracy of our implementation for **fer2013** dataset: **0.7088**
# - We have achieved our objective which was to supass the accuracy of **0.69**
# - Eventhough our implementation was based on **paper [1]** we could not reach the accuracy they have reported (**0.72**)
# - The Kaggle winning method reports an accuracy **0.712** which is based on **paper [5]**
# - **Paper [4]** has reported an accuracy of f **0.7510** for the Kaggle Challenge

# %% [markdown]
# ## 2.2 Suggestion to further imporve the accuracy
# - implement **paper [4]**
# - use data augmentation
#     - find data from other sources as well

# %% [markdown]
# ## 2.3 Some observaions
#  - the training and validaton class distribution is very different
#  - the training class distribution is not balanced
#  - the validation accuracy and private leader board accuracy are very close
#      - their class distribution is also very close

# %% [markdown]
# # 3 Instruction to run the tutorial

# %% [markdown]
# - make sure the dataset **fer2013.csv** and **badtrainingdata.txt** is available in the same folder where this ipython note book file is placed
# - check Cell **4.5 Global settings** and update the settings according to your need
# - start running the code from Cell **4 Code Implementation**

# %% [markdown]
# # 4  Code Implementation

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization
from keras.layers import Convolution2D, MaxPooling2D, Conv2D
from keras.layers import AveragePooling2D
from keras.optimizers import Adadelta ,SGD 
from keras.utils import np_utils
from keras.models import load_model
from keras.regularizers import l2, l1
from keras.layers import deserialize as layer_from_config
import keras.backend as K
from keras.callbacks import ModelCheckpoint
from keras.callbacks import CSVLogger 
from keras.callbacks import History 
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
# Out:
# /usr/local/lib/python3.6/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
import numpy as np
import pandas as pd
import itertools
from sklearn.metrics import confusion_matrix
from sklearn.utils import class_weight 
from sklearn import cross_validation
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
plt.rcParams['figure.figsize'] = (8,6)
plt.style.use('ggplot')
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
import copy
import csv

# %% [markdown]
# ## 4.1 Helper functions- to load and pre-process the data
#
# These helper functions are taken from https://github.com/LamUong/FacialExpressionRecognition/blob/master/dataprocessing.py
# These functins saves us a lot of trouble. The image data is given in a csv (fer2013.csv) file. And these functions helps us to easyly load tesing and training data. The author has also identified few bad training data and listed out in "badtrainingdata.txt".

# %%
from __future__ import print_function
import _pickle as cPickle
import numpy
import csv
import scipy.misc
import scipy
from scipy import ndimage
import imutils
import cv2
import numpy as np
from keras.preprocessing.image import ImageDataGenerator

import PIL
from PIL import Image
from numpy import array

# %% [markdown]
# The following helper function from class **HelperDataProcessing** will be used in this tutorial frequently.
# - `load_test_data()`:
# <br> returns x_test, y_test
# <br> x_test - testing images of **fer2013**,  x_test is of type list, x_test[0] is of numpy.ndarray, x_test[0].shape is (48, 48)
# <br> y_test - labels corresponding to x_test, y_test is of type list, y_test[0] is of type int
# - `load_data()`:
# <br> returns x_train, y_train, x_val, y_val
# <br> x_train - training images of **fer2013**,  x_train is of type list, x_train[0] is also of type list
# <br> y_train - labels corresponding to x_train, y_train is of type list, y_train[0] is of type int
# <br> x_val   - validation images of **fer2013**,  x_val is of type list, x_val[0] is also of type list
# <br> y_val   - labels corresponding to x_val, y_val is of type list, y_val[0] is of type int
# - `get_formatted_train_val_data()`:
# <br> returns X_train, Y_train, X_val, Y_val:
# <br> X_train - training images of **fer2013**,  X_train is of type numpy.ndarray, X_train[0] is also of type numpy.ndarray, shape of X_train[0] is (48, 48, 1)
# <br> Y_train - labels corresponding to X_train, Y_train is of type numpy.ndarray, Y_train[0] is of type numpy.ndarray, shape of Y_train[0] is (7,)
# <br> X_val   - validation images of **fer2013**,  X_val is of type numpy.ndarray, X_val[0] is also of type numpy.ndarray, shape of X_val[0] is (48, 48, 1)
# <br> Y_val - labels corresponding to X_val, Y_val is of type numpy.ndarray, Y_val[0] is of type numpy.ndarray, shape of Y_val[0] is (7,)
# - `get_formatted_private_test_data()`:
# <br> returns X_test, Y_test:
# <br> X_test   - validation images of **fer2013**,  X_test is of type numpy.ndarray, X_test[0] is also of type numpy.ndarray, shape of X_test[0] is (48, 48, 1)
# <br> Y_test - labels corresponding to X_test, Y_test is of type numpy.ndarray, Y_test[0] is of type numpy.ndarray, shape of Y_test[0] is (7,)

# %%
class HelperDataProcessing:

    @staticmethod
    def flatten_matrix(matrix):
        vector = matrix.flatten(1)
        vector = vector.reshape(1, len(vector))
        return vector
    
    @staticmethod
    def zca_whitening(inputs):
        sigma = np.dot(inputs, inputs.T)/inputs.shape[1] #Correlation matrix
        U,S,V = np.linalg.svd(sigma) #Singular Value Decomposition
        epsilon = 0.1                #Whitening constant, it prevents division by zero
        ZCAMatrix = np.dot(np.dot(U, np.diag(1.0/np.sqrt(np.diag(S) + epsilon))), U.T)                     #ZCA Whitening matrix
        return np.dot(ZCAMatrix, inputs)   #Data whitening

    @staticmethod
    def global_contrast_normalize(X, scale=1., subtract_mean=True, use_std=True,
                                  sqrt_bias=10, min_divisor=1e-8):

        """
        __author__ = "David Warde-Farley"
        __copyright__ = "Copyright 2012, Universite de Montreal"
        __credits__ = ["David Warde-Farley"]
        __license__ = "3-clause BSD"
        __email__ = "wardefar@iro"
        __maintainer__ = "David Warde-Farley"
        .. [1] A. Coates, H. Lee and A. Ng. "An Analysis of Single-Layer
           Networks in Unsupervised Feature Learning". AISTATS 14, 2011.
           http://www.stanford.edu/~acoates/papers/coatesleeng_aistats_2011.pdf
        """
        assert X.ndim == 2, "X.ndim must be 2"
        scale = float(scale)
        assert scale >= min_divisor

        mean = X.mean(axis=1)
        if subtract_mean:
            X = X - mean[:, numpy.newaxis]  
        else:
            X = X.copy()
        if use_std:
            ddof = 1
            if X.shape[1] == 1:
                ddof = 0
            normalizers = numpy.sqrt(sqrt_bias + X.var(axis=1, ddof=ddof)) / scale
        else:
            normalizers = numpy.sqrt(sqrt_bias + (X ** 2).sum(axis=1)) / scale
        normalizers[normalizers < min_divisor] = 1.
        X /= normalizers[:, numpy.newaxis]  # Does not make a copy.
        return X
    
    @staticmethod
    def ZeroCenter(data):
        data = data - numpy.mean(data,axis=0)
        return data

    @staticmethod
    def normalize(arr):
        for i in range(3):
            minval = arr[...,i].min()
            maxval = arr[...,i].max()
            if minval != maxval:
                arr[...,i] -= minval
                arr[...,i] *= (255.0/(maxval-minval))
        return arr

    @staticmethod
    def Flip(data):
        dataFlipped = data[..., ::-1].reshape(2304).tolist()
        return dataFlipped

    @staticmethod
    def Roated15Left(data):
        num_rows, num_cols = data.shape[:2]
        rotation_matrix = cv2.getRotationMatrix2D((num_cols/2, num_rows/2), 30, 1)
        img_rotation = cv2.warpAffine(data, rotation_matrix, (num_cols, num_rows))
        return img_rotation.reshape(2304).tolist()

    @staticmethod
    def Roated15Right(data):
        num_rows, num_cols = data.shape[:2]
        rotation_matrix = cv2.getRotationMatrix2D((num_cols/2, num_rows/2), -30, 1)
        img_rotation = cv2.warpAffine(data, rotation_matrix, (num_cols, num_rows))
        return img_rotation.reshape(2304).tolist()

    @staticmethod
    def Zoomed(data):
        datazoomed = scipy.misc.imresize(data,(60,60))
        datazoomed = datazoomed[5:53,5:53]
        datazoomed = datazoomed.reshape(2304).tolist()
        return datazoomed

    @staticmethod
    def shiftedUp20(data):
        translated = imutils.translate(data, 0, -5)
        translated2 = translated.reshape(2304).tolist()
        return translated2
    
    @staticmethod
    def shiftedDown20(data):
        translated = imutils.translate(data, 0, 5)
        translated2 = translated.reshape(2304).tolist()
        return translated2

    @staticmethod
    def shiftedLeft20(data):
        translated = imutils.translate(data, -5, 0)
        translated2 = translated.reshape(2304).tolist()
        return translated2
    
    @staticmethod
    def shiftedRight20(data):
        translated = imutils.translate(data, 5, 0)
        translated2 = translated.reshape(2304).tolist()
        return translated2
    
    @staticmethod
    def outputImage(pixels,number):
        data = pixels
        name = str(number)+"output.jpg" 
        scipy.misc.imsave(name, data)

    @staticmethod
    def Zerocenter_ZCA_whitening_Global_Contrast_Normalize(list):
        Intonumpyarray = numpy.asarray(list)
        data = Intonumpyarray.reshape(48,48)
        data2 = HelperDataProcessing.ZeroCenter(data)
        data3 = HelperDataProcessing.zca_whitening(HelperDataProcessing.flatten_matrix(data2)).reshape(48,48)
        data4 = HelperDataProcessing.global_contrast_normalize(data3)
        data5 = numpy.rot90(data4,3)
        return data5

    @staticmethod
    def load_test_data():
        f = open('fer2013.csv')
        csv_f = csv.reader(f)
        test_set_x =[]
        test_set_y =[]
        for row in csv_f:  
            if str(row[2]) == "PrivateTest" :
                test_set_y.append(int(row[0]))
                temp_list = []
                for pixel in row[1].split( ):
                    temp_list.append(int(pixel))
                data = HelperDataProcessing.Zerocenter_ZCA_whitening_Global_Contrast_Normalize(temp_list)
                test_set_x.append(data)
        return test_set_x, test_set_y

    @staticmethod
    def load_data():

        train_x = []
        train_y = []
        val_x =[]
        val_y =[]

        with open("badtrainingdata.txt", "r") as text:
            ToBeRemovedTrainingData = []
            for line in text:
                ToBeRemovedTrainingData.append(int(line))
        number = 0

        f = open('fer2013.csv')
        csv_f = csv.reader(f)

        for row in csv_f:   
            number+= 1
            if number not in ToBeRemovedTrainingData:

                if str(row[2]) == "Training" or str(row[2]) == "PublicTest" :
                    temp_list = []

                    for pixel in row[1].split( ):
                        temp_list.append(int(pixel))

                    data = HelperDataProcessing.Zerocenter_ZCA_whitening_Global_Contrast_Normalize(temp_list)
                    train_y.append(int(row[0]))
                    train_x.append(data.reshape(2304).tolist())

                elif str(row[2]) == "PrivateTest":
                    temp_list = []

                    for pixel in row[1].split( ):
                        temp_list.append(int(pixel))

                    data = HelperDataProcessing.Zerocenter_ZCA_whitening_Global_Contrast_Normalize(temp_list)
                    val_y.append(int(row[0]))
                    val_x.append(data.reshape(2304).tolist())

        return train_x, train_y, val_x, val_y
    
    @staticmethod
    def get_formatted_train_val_data():

        X_train, y_train, X_val, y_val  = HelperDataProcessing.load_data()

        for i in range(len(X_train)):
            X_train[i] = (np.array(X_train[i])).reshape(48, 48, 1)

        X_train= np.array(X_train)

        for i in range(len(X_val)):
            X_val[i] = (np.array(X_val[i])).reshape(48, 48, 1)

        X_val= np.array(X_val)

        y_train = np.array(y_train)
        y_val   = np.array(y_val)

        # Convert 1-dimensional class arrays to 10-dimensional class matrices
        Y_train = np_utils.to_categorical(y_train, 7)
        Y_val = np_utils.to_categorical(y_val, 7)

        return X_train, Y_train, X_val, Y_val

    @staticmethod
    def get_formatted_private_test_data():

        X_private_test, y_private_test  = HelperDataProcessing.load_test_data()

        for i in range(len(X_private_test)):
            X_private_test[i] = (np.array(X_private_test[i])).reshape(48, 48, 1)

        X_private_test= np.array(X_private_test)
        Y_private_test = np_utils.to_categorical(y_private_test, 7)

        return X_private_test, Y_private_test

# %% [markdown]
# ## 4.2 Helper functions to test model on peturbed data
# These helper functions are taken from https://github.com/LamUong/FacialExpressionRecognition/blob/master/averagemethod.py and modified according to our needs

# %%
def predict_prob(number,test_set_x,model):
    data_p = []
    for data in test_set_x:
        if number ==0:
            data_p.append(HelperDataProcessing.Flip(data))
        elif number ==1:
            data_p.append(HelperDataProcessing.Roated15Left(data))
        elif number ==2:
            data_p.append(HelperDataProcessing.Roated15Right(data))
        elif number ==3:
            data_p.append(HelperDataProcessing.shiftedUp20(data))
        elif number ==4:
            data_p.append(HelperDataProcessing.shiftedDown20(data))
        elif number ==5:
            data_p.append(HelperDataProcessing.shiftedLeft20(data))
        elif number ==6:
            data_p.append(HelperDataProcessing.shiftedRight20(data))
        elif number ==7:
            data_p.append(data)
    
    #Covert the data to Numpy format
    for i in range(len(data_p)):
        data_p[i] = (np.array(data_p[i])).reshape(48, 48, 1)
        
    X_private_test= np.array(data_p)
            
    proba = model.predict_proba(X_private_test)
    return proba

# %% [markdown]
# ## 4.3 Helper functions to dispaly and analyze  data
# These helper functions<br/>
#
# - `plot_confusion_matrix()`: helps us to plot the confusion matrix. <br/> It is taken from http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html. <br/>The same page has some sample examples on how to use this function
#
# - `plot_histogram()`: helps to plot the histogram of a list

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm) #to print in text if needed

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
def plot_histogram(lst_data, class_labels, ylabel='None', title='None'):
    data = pd.Series(lst_data)
    distribution = data.value_counts(sort=False)
    y_pos = np.arange(len(class_labels))
    
    plt.bar(y_pos, distribution, align='center', alpha=0.8)
    plt.xticks(y_pos, class_labels)
    plt.ylabel(ylabel)
    plt.title(title)

# %%
class HelperPlotLogs():
    def __init__(self, *file_names):
        self.__file_names  = []
        self.__data_frames = []
        self.__design      = ['r--', 'b--', 'g--', 'p--']
        
        for file_name in file_names:
            self.__file_names.append(file_name)
 
        for file_name in self.__file_names:
            self.__data_frames.append(pd.read_csv(file_name))
            print(self.__data_frames[-1].columns)

        #print(self.__data_frames[0].columns)
        #print(self.__data_frames[1].columns)
        columns = len(self.__data_frames[0].columns)
        
        for df in  self.__data_frames:
            if columns- len(df.columns):
                print("Header not matching")
        
    def plot_aganist(self, val):
        file_index = 1
        for df, design  in  zip(self.__data_frames, self.__design):
            plt.plot(df[val], design, label='file_'+str(file_index))
            file_index += 1
        
        plt.ylabel(val)
        plt.legend(loc='best')
        plt.show()

            
    def plot_same(self, *vals, file_number=0):
        for val, design in zip(vals, self.__design):
            plt.plot(self.__data_frames[file_number][val], design, label=val)
            
        plt.ylabel(vals)
        plt.legend(loc='best')
        plt.show()
        
    def plot_same_aganist(self, *vals, file_numbers=[0]):
        rows  = 1
        cols  = len(file_numbers)
        file_index = 1
        #plt.subplots_adjust(hspace=0.4, wspace=0.4)
        
        for file_number in file_numbers:            
            for val, design in zip(vals, self.__design):
                #plt.subplot(rows, cols, file_index)
                plt.plot(self.__data_frames[file_number][val], design, label=val)
            file_index += 1
            
            plt.ylabel(vals)
            plt.legend(loc='best')      
            plt.show()

    @staticmethod        
    def save_dict_to_csv(file_name, dict_list_1, write_header=True, write_mode='w'):
        """If give two dictionaries this function will 
            put them in a file_name.csv file"""

        if len(dict_list_1) != 0:
            print("Lengths of list not matching")
            return

        fieldnames = []
        dict1 = dict_list_1[0]

        for field in dict1:
            fieldnames.append(field)

        with open(file_name, write_mode) as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

            if write_header:
                writer.writeheader()

            for dict1 in dict_list_1:
                writer.writerow(dict1)
                
    @staticmethod
    def save_2dict_to_csv(file_name, dict_list_1, dict_list_2, write_header=True, write_mode='w'):
        """If give two dictionaries this function will 
            put them in a file_name.csv file
            typical usage:
            save_2dict_to_csv(file_prefix+ r"my_logger.csv", my_logger.logs, my_logger.optimizer_parms)"""

        #dict_list_1 = copy.deepcopy(dict_list_1_tmp)

        if len(dict_list_1) != len(dict_list_2):
            print("Lengths of list not matching")
            return

        fieldnames = []
        dict1 = dict_list_1[0]
        dict2 = dict_list_2[0]

        for field in dict1:
            fieldnames.append(field)

        for field in dict2:
            fieldnames.append(field)

        with open(file_name, write_mode) as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

            if write_header:
                writer.writeheader()

            for dict1, dict2 in zip(dict_list_1, dict_list_2):
                #dict1_c = copy.deepcopy(dict1)
                #dict2_c = copy.deepcopy(dict2)
                dict1.update(dict2)
                writer.writerow(dict1)

# %%
class My_Logger(keras.callbacks.Callback):
    def __init__(self):
        self.global_epoch = 0
        self.optimizer_parms = []
        self.logs = []
        self.wrote_header = False
        
    def on_train_begin(self, logs={}):    
        return
 
    def on_train_end(self, logs={}):
        return
 
    def on_epoch_begin(self,  epoch, logs={}):
        return
 
    def on_epoch_end(self, epoch, logs={}):
        optimizer_name = self.model.optimizer
        optimizer_param =  copy.deepcopy((self.model.optimizer.get_config()))
        #print(optimizer_param)
        optimizer_param['g_epoch']  = self.global_epoch
        optimizer_param['l_epoch']  = epoch
        
        self.optimizer_parms.append(optimizer_param)
 
        log_dict = copy.deepcopy(logs)

        log_dict['opt_name'] = optimizer_name
        self.logs.append(log_dict)
        #print(self.logs)
        
        self.global_epoch   = self.global_epoch + 1
        return
 
    def on_batch_begin(self, batch, logs={}):
        return
 
    def on_batch_end(self, batch, logs={}):
        return

# %% [markdown]
# ## 4.5 Global settings
#
# Preferably this should be the only place where we should be changing global settings for this tutorial
#
# **Global Settings**:
# - `file_prefix`: All files (logs, saved model) fill have this string as the prefix. Useful when we run multiple trials.
# - `do_sub_sampling_of_input`: if set to **True** then training and validation happens on only 25% of train and validation samples of fer2013.csv this helps us to do fast training to check the feasibility of a model. if **False** then we use the full data set for Training and Validation
# - `Facial_Expressions`: list of **Facial Expressions** and the index of each Facial Expression in the list is same as the class number used in fer2013.csv. <br/> For example index of **'Angry'** is **0** and the class number used for angry faces is also **0**. <br/> Index of **'Happy'** is **3** and the class number used for happy faces is also **3**. <br/> In fer2013.csv class number  0 is for Angry, 1 for Disgust, 2 for Fear, 3 for Happy, 4 for Neutral, 5 for Sad and 6 for Surprise.
# - `ModelPerformance`: is a pandas DataFrame which we use to keep track of different methods and it's accuracies.<br> We can add data to the DataFrame like this, ModelPerformance.loc[len(ModelPerformance)] = ['method1',  69.7]
# - `do_data_appending`: if set to **True** then the training data is appended by a copy of itself. While we do data augmentation using ImageDataGenerator, the input samples gets modified. ImageDataGenerator randomly picks up samples(based on some probability) and modifies it. Doubling the training data samples make sure that orginal samples get more weightage in training. Because it is unlikely that ImageDataGenerator picks up the same sample again. if set to **False** then no appeding

# %%
file_prefix               = "Final_Subm_FER_Tony_v1_"  
do_sub_sampling_of_input  = False
Facial_Expressions        = ['Anger', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Suprise']
ModelPerformance          = pd.DataFrame(columns=['method_name','accuracy'])
do_data_appending         = True

# %% [markdown]
# # 5. Exploratory data analysis
# The goal is to build some intuition around the data

# %% [markdown]
# ## 5.1 Load Training and Validation data (Public Leader Board data)

# %%
X_train, Y_train, X_val, Y_val = HelperDataProcessing.get_formatted_train_val_data() #usually take some time to load the data
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: Non-string object detected for the array ordering. Please pass in 'C', 'F', 'A', or 'K' instead
#   """

# %% [markdown]
# ## 5.2 Load Test data (Private Leader Board data)

# %%
X_private_test, Y_private_test = HelperDataProcessing.get_formatted_private_test_data() #usually takes some time to load the data
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: Non-string object detected for the array ordering. Please pass in 'C', 'F', 'A', or 'K' instead
#   """

# %% [markdown]
# ##### Check the dimensions of train, validation and test data

# %%
print(X_train.shape, Y_train.shape, X_val.shape, Y_val.shape)
# Out:
# (32181, 48, 48, 1) (32181, 7) (3589, 48, 48, 1) (3589, 7)

# %%
print(X_private_test.shape, Y_private_test.shape)
# Out:
# (3589, 48, 48, 1) (3589, 7)

# %% [markdown]
# ## 5.3 Check the class distribution
#
# Checking the data distribution requires loading the facial expresson classes, not the one hot encoded version of class.
# So we need to load the labels again for testing and validation data

# %%
x_train, y_train, x_val, y_val = HelperDataProcessing.load_data()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: Non-string object detected for the array ordering. Please pass in 'C', 'F', 'A', or 'K' instead
#   """

# %%
print("Training Data Class Distribution\n",pd.Series(y_train).value_counts(sort=False))
print("Validation Data Class Distribution\n",pd.Series(y_val).value_counts(sort=False))
# Out:
# Training Data Class Distribution
#  0    4441
# 1     491
# 2    4574
# 3    8088
# 4    5460
# 5    3575
# 6    5552
# dtype: int64
# Validation Data Class Distribution
#  0    491
# 2    528
# 4    594
# 6    626
# 1     55
# 3    879
# 5    416
# dtype: int64

# %%
plot_histogram(y_train, Facial_Expressions, ylabel='Frequency',title='Facial Expression Class Distribution in Training Data')

# %%
plot_histogram(y_val, Facial_Expressions, ylabel='Frequency',title='Facial Expression Class Distribution in Validation Data')

# %% [markdown]
# ## 5.5 Observations from inspecting the data set

# %% [markdown]
# #### Handle the class distribution  imbalance
#
# - We can see that there is an imbalance in the class distribution in Training data set. Also, Training and Validaton data set distribution is totally different too. This means in Testing/real world scenarios we can expect any kind of distribution.
# <br/>
# <br/>
# - We have 3 options here
#  - use class_weights argument in model.fit() and make the model learn more from minority classes
#  - reduce the majority class sized to make the distribution balanced (not a very good one, as we don't have much data)
#  - data augmentation for minority classes
# <br/>
# <br/>
# - We will try
#  - using class_weights argument, in model.fit()
#  - and if time allows data augmentation of minority class aswell

# %% [markdown]
# #### Calculating class weights

# %%
class_weights = class_weight.compute_class_weight('balanced', np.unique(y_train), y_train)

# %% [markdown]
# #### Verifying the class weights
# The weights should be such that <br/>
# $w_0*n_0 = w_1*n_1 =... == w_6*n_6$
# <br/>
# where, $w_i$ is class weights and $n_i$ is number of samples in a class

# %%
class_weights* pd.Series(y_train).value_counts(sort=False)
# Out:
# 0   4597.29
# 1   4597.29
# 2   4597.29
# 3   4597.29
# 4   4597.29
# 5   4597.29
# 6   4597.29
# dtype: float64

# %% [markdown]
# # 6. Build and Train the model
#
# The model is based on paper [1]

# %% [markdown]
# #### Define all custom cost functions here

# %% [markdown]
# #### rmse_fer
# This function is used to monitor the root mean squared error in the non-predicted classes<br>
# This will help us to know the confidence of prediction

# %%
def rmse_fer(y_true, y_pred):
        
    ce_loss = 0.0
    
    rmse_loss = K.sqrt(K.mean(K.square((y_pred - y_true)*(1 - y_true)), axis=-1))
    
    return rmse_loss

# %% [markdown]
# #### Define all the callback functions needed here

# %%
#Callback for saving the best model

filepath = file_prefix + r".best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# %%
csv_log_file = file_prefix + r".csv"
csv_logger   = keras.callbacks.CSVLogger(csv_log_file, separator=',', append=True)

# %%
#from keras.callbacks import ReduceLROnPlateau 

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001)

# %%
my_logger  = My_Logger()

# %%
history = History()

# %%
#callbacks_list = [checkpoint, history, csv_logger, my_logger, clr_triangular]
callbacks_list = [checkpoint, history, csv_logger, my_logger]

# %%
K.clear_session() #Useful to clear the session from GPU

# %% [markdown]
# ### Intitilisation for different optimizers
# 1. sgd      = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
# 2. adadelta = Adadelta(lr=0.1, rho=0.95, epsilon=1e-08)
# 3. rmsprop  = RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)
# 4. adagrad  = Adagrad(lr=0.01, epsilon=1e-08, decay=0.0)
# 5. adam     = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

# %% [markdown]
# ### Sub sample the data

# %%
if do_sub_sampling_of_input:
    X_, X_train, Y_, Y_train = cross_validation.train_test_split(X_train, Y_train, test_size=0.25, random_state=0)
    X_, X_val,  Y_, Y_val    = cross_validation.train_test_split(X_val, Y_val, test_size=0.25, random_state=0)
    print("After SubSampling", X_train.shape, Y_train.shape, X_val.shape, Y_val.shape)

# %% [markdown]
# ### Data Augmentation

# %%
if do_data_appending:
    X_train = np.append(X_train, X_train,axis=0)
    Y_train = np.append(Y_train, Y_train,axis=0)

# %%
#Data Augmentation

datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=25,  # randomly rotate images in the range (degrees, 0 to 180)
        width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False,    # randomly flip images
        fill_mode='nearest')

# %% [markdown]
# ### 6.1 Train the model

# %%
def model_generate():
    img_rows, img_cols = 48, 48

    model = Sequential()
    model.add(Convolution2D(128, kernel_size=(5, 5), padding='same', input_shape=(img_rows, img_cols, 1)))
    model.add(Activation('relu'))
    model.add(BatchNormalization())

    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.1))
    
    model.add(Convolution2D(128, kernel_size=(3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())  
    model.add(Dropout(0.3))
        
    model.add(Convolution2D(128, kernel_size=(3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization()) 
    
    model.add(MaxPooling2D(pool_size=(3, 3),strides=(2, 2)))
    model.add(Dropout(0.3))

    model.add(Convolution2D(128, kernel_size=(3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    
    model.add(Convolution2D(128, kernel_size=(3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    
    model.add(MaxPooling2D(pool_size=(3, 3),strides=(2, 2)))
    model.add(Dropout(0.3))
    
    model.add(Conv2D(512, 3, 3))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    
    model.add(Flatten())
    model.add(Dense(2048))
    model.add(Activation('relu'))
    model.add(Dropout(0.25))
    
    model.add(Dense(1024))
    model.add(Activation('relu'))
    model.add(Dropout(0.25))
    
    model.add(Dense(1024))
    model.add(Activation('relu'))
    model.add(Dropout(0.25))

    model.add(Dense(7))
    model.add(Activation('softmax'))

    #ada = Adadelta(lr=0.1, rho=0.95, epsilon=1e-08)
    sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
    #adam = keras.optimizers.Adam()
    
    model.compile(loss='categorical_crossentropy',
    optimizer=sgd,
    metrics=['accuracy',rmse_fer])
    
    model.summary()
    
    return model

# %%
try:
    del model_cnn # if model exist delete it
except NameError:
    pass
    
model_cnn = model_generate()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:36: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3))`
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 48, 48, 128)       3328
# _________________________________________________________________
# activation_1 (Activation)    (None, 48, 48, 128)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 48, 48, 128)       512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 24, 24, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24, 24, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 24, 24, 128)       147584
# _________________________________________________________________
# activation_2 (Activation)    (None, 24, 24, 128)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 24, 24, 128)       512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 24, 24, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 24, 24, 128)       147584
# _________________________________________________________________
# activation_3 (Activation)    (None, 24, 24, 128)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 24, 24, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 11, 11, 128)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 11, 11, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 11, 11, 128)       147584
# _________________________________________________________________
# activation_4 (Activation)    (None, 11, 11, 128)       0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 11, 11, 128)       512
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 11, 11, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 11, 11, 128)       147584
# _________________________________________________________________
# activation_5 (Activation)    (None, 11, 11, 128)       0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 11, 11, 128)       512
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 128)         0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 5, 5, 128)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 3, 3, 512)         590336
# _________________________________________________________________
# activation_6 (Activation)    (None, 3, 3, 512)         0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 3, 3, 512)         2048
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2048)              9439232
# _________________________________________________________________
# activation_7 (Activation)    (None, 2048)              0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# activation_8 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# activation_9 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 7)                 7175
# _________________________________________________________________
# activation_10 (Activation)   (None, 7)                 0
# =================================================================
# Total params: 13,782,791
# Trainable params: 13,780,487
# Non-trainable params: 2,304
# _________________________________________________________________

# %%
batch_size = 128
nb_classes = 7
if do_sub_sampling_of_input:
    nb_epcohs = 200
else:
    nb_epcohs = 200

# %%
model_cnn.fit_generator(datagen.flow(X_train, Y_train,
          batch_size=batch_size),
          epochs=nb_epcohs,
          verbose=1,
          class_weight=class_weights,
          validation_data=(X_val, Y_val),
          callbacks=callbacks_list)
# Out:
# WARNING:tensorflow:Variable *= will be deprecated. Use variable.assign_mul if you want assignment to the variable value or 'x = x * y' if you want a new python Tensor object.
# Epoch 1/200
# 503/503 [==============================] - 81s 162ms/step - loss: 1.7902 - acc: 0.2651 - rmse_fer: 0.1479 - val_loss: 1.6246 - val_acc: 0.3408 - val_rmse_fer: 0.1435
#
# Epoch 00001: val_acc improved from -inf to 0.34076, saving model to Final_Subm_FER_Tony_v1_.best.hdf5
# Epoch 2/200
# 503/503 [==============================] - 78s 156ms/step - loss: 1.6248 - acc: 0.3523 - rmse_fer: 0.1434 - val_loss: 1.5415 - val_acc: 0.3970 - val_rmse_fer: 0.1435
#
# Epoch 00002: val_acc improved from 0.34076 to 0.39705, saving model to Final_Subm_FER_Tony_v1_.best.hdf5
# Epoch 3/200
# 503/503 [==============================] - 78s 156ms/step - loss: 1.4974 - acc: 0.4152 - rmse_fer: 0.1403 - val_loss: 1.3563 - val_acc: 0.4675 - val_rmse_fer: 0.1391
#
# Epoch 00003: val_acc improved from 0.39705 to 0.46754, saving model to Final_Subm_FER_Tony_v1_.best.hdf5
# Epoch 4/200
# 503/503 [==============================] - 78s 156ms/step - loss: 1.4148 - acc: 0.4553 - rmse_fer: 0.1378 - val_loss: 1.3405 - val_acc: 0.4882 - val_rmse_fer: 0.1367
#
# Epoch 00004: val_acc improved from 0.46754 to 0.48816, saving model to Final_Subm_FER_Tony_v1_.best.hdf5
# Epoch 5/200
# 503/503 [==============================] - 78s 156ms/step - loss: 1.3658 - acc: 0.4758 - rmse_fer: 0.1369 - val_loss: 1.2969 - val_acc: 0.4993 - val_rmse_fer: 0.1405
#
# Epoch 00005: val_acc improved from 0.48816 to 0.49930, saving model to Final_Subm_FER_Tony_v1_.best.hdf5
# Epoch 6/200
# 503/503 [==============================] - 78s 156ms/step - loss: 1.3167 - acc: 0.4972 - rmse_fer: 0.1356 - val_loss: 1.2136 - val_acc: 0.5364 - val_rmse_fer: 0.1319
#
# Epoch 00006: val_acc improved from 0.49930 to 0.53636, saving model to Final_Subm_FER_Tony_v1_.best.hdf5
# Epoch 7/200
# 503/503 [==============================] - 78s 156ms/step - loss: 1.2789 - acc: 0.5130 - rmse_fer: 0.1342 - val_loss: 1.1938 - val_acc: 0.5339 - val_rmse_fer: 0.1306
#
# Epoch 00007: val_acc did not improve from 0.53636
# Epoch 8/200
# 503/503 [==============================] - 78s 156ms/step - loss: 1.2522 - acc: 0.5220 - rmse_fer: 0.1333 - val_loss: 1.1751 - val_acc: 0.5442 - val_rmse_fer: 0.1331
#
# Epoch 00008: val_acc improved from 0.53636 to 0.54416, saving model to Final_Subm_FER_Tony_v1_.best.hdf5
# Epoch 9/200
# 503/503 [==============================] - 78s 156ms/step - loss: 1.2271 - acc: 0.5316 - rmse_fer: 0.1325 - val_loss: 1.1305 - val_acc: 0.5678 - val_rmse_fer: 0.1301
#
# Epoch 00009: val_acc improved from 0.54416 to 0.56785, saving model to Final_Subm_FER_Tony_v1_.best.hdf5
# Epoch 10/200
# 503/503 [==============================] - 78s 156ms/step - loss: 1.2050 - acc: 0.5428 - rmse_fer: 0.1318 - val_loss: 1.1363 - val_acc: 0.5606 - val_rmse_fer: 0.1322
#
# Epoch 00010: val_acc did not improve from 0.56785
# Epoch 11/200
# 503/503 [==============================] - 78s 156ms/step - loss: 1.1857 - acc: 0.5517 - rmse_fer: 0.1308 - val_loss: 1.0568 - val_acc: 0.5952 - val_rmse_fer: 0.1263
#
# Epoch 00011: val_acc improved from 0.56785 to 0.59515, saving model to Final_Subm_FER_Tony_v1_.best.hdf5
# Epoch 12/200
# 503/503 [==============================] - 79s 156ms/step - loss: 1.1674 - acc: 0.5586 - rmse_fer: 0.1298 - val_loss: 1.1019 - val_acc: 0.5765 - val_rmse_fer: 0.1306
#
# Epoch 00012: val_acc did not improve from 0.59515
# Epoch 13/200
# 503/503 [==============================] - 79s 156ms/step - loss: 1.1525 - acc: 0.5616 - rmse_fer: 0.1293 - val_loss: 1.0370 - val_acc: 0.5985 - val_rmse_fer: 0.1236
#
# Epoch 00013: val_acc improved from 0.59515 to 0.59850, saving model to Final_Subm_FER_Tony_v1_.best.hdf5
# Epoch 14/200
# 503/503 [==============================] - 78s 156ms/step - loss: 1.1399 - acc: 0.5686 - rmse_fer: 0.1288 - val_loss: 1.0515 - val_acc: 0.6041 - val_rmse_fer: 0.1253
#
# Epoch 00014: val_acc improved from 0.59850 to 0.60407, saving model to Final_Subm_FER_Tony_v1_.best.hdf5
# Epoch 15/200
# 503/503 [==============================] - 78s 156ms/step - loss: 1.1255 - acc: 0.5743 - rmse_fer: 0.1280 - val_loss: 1.0634 - val_acc: 0.5957 - val_rmse_fer: 0.1248
#
# Epoch 00015: val_acc did not improve from 0.60407
# Epoch 16/200
# 503/503 [==============================] - 78s 156ms/step - loss: 1.1144 - acc: 0.5794 - rmse_fer: 0.1274 - val_loss: 1.0209 - val_acc: 0.6060 - val_rmse_fer: 0.1213
#
# Epoch 00016: val_acc improved from 0.60407 to 0.60602, saving model to Final_Subm_FER_Tony_v1_.best.hdf5
# Epoch 17/200
# 503/503 [==============================] - 78s 156ms/step - loss: 1.1061 - acc: 0.5836 - rmse_fer: 0.1270 - val_loss: 1.0178 - val_acc: 0.6133 - val_rmse_fer: 0.1210
#
# Epoch 00017: val_acc improved from 0.60602 to 0.61326, saving model to Final_Subm_FER_Tony_v1_.best.hdf5
# Epoch 18/200
# 503/503 [==============================] - 79s 156ms/step - loss: 1.0979 - acc: 0.5866 - rmse_fer: 0.1265 - val_loss: 0.9973 - val_acc: 0.6155 - val_rmse_fer: 0.1210
#
# Epoch 00018: val_acc improved from 0.61326 to 0.61549, saving model to Final_Subm_FER_Tony_v1_.best.hdf5
# Epoch 19/200
# 503/503 [==============================] - 79s 156ms/step - loss: 1.0860 - acc: 0.5894 - rmse_fer: 0.1260 - val_loss: 1.0161 - val_acc: 0.6138 - val_rmse_fer: 0.1240
#
# Epoch 00019: val_acc did not improve from 0.61549
# Epoch 20/200
# 503/503 [==============================] - 79s 156ms/step - loss: 1.0778 - acc: 0.5936 - rmse_fer: 0.1257 - val_loss: 0.9893 - val_acc: 0.6205 - val_rmse_fer: 0.1234
#
# Epoch 00020: val_acc improved from 0.61549 to 0.62051, saving model to Final_Subm_FER_Tony_v1_.best.hdf5
# Epoch 21/200
# 503/503 [==============================] - 78s 156ms/step - loss: 1.0678 - acc: 0.5967 - rmse_fer: 0.1251 - val_loss: 0.9828 - val_acc: 0.6244 - val_rmse_fer: 0.1219
#
# Epoch 00021: val_acc improved from 0.62051 to 0.62441, saving model to Final_Subm_FER_Tony_v1_.best.hdf5
# Epoch 22/200
# 503/503 [==============================] - 79s 156ms/step - loss: 1.0589 - acc: 0.5998 - rmse_fer: 0.1246 - val_loss: 0.9869 - val_acc: 0.6333 - val_rmse_fer: 0.1202
#
# Epoch 00022: val_acc improved from 0.62441 to 0.63332, saving model to Final_Subm_FER_Tony_v1_.best.hdf5
# Epoch 23/200
# 503/503 [==============================] - 78s 156ms/step - loss: 1.0524 - acc: 0.6028 - rmse_fer: 0.1242 - val_loss: 0.9794 - val_acc: 0.6233 - val_rmse_fer: 0.1211
#
# Epoch 00023: val_acc did not improve from 0.63332
# Epoch 24/200
# 503/503 [==============================] - 79s 156ms/step - loss: 1.0463 - acc: 0.6055 - rmse_fer: 0.1240 - val_loss: 0.9794 - val_acc: 0.6244 - val_rmse_fer: 0.1241
#
# Epoch 00024: val_acc did not improve from 0.63332
# Epoch 25/200
# 503/503 [==============================] - 78s 156ms/step - loss: 1.0397 - acc: 0.6074 - rmse_fer: 0.1238 - val_loss: 0.9664 - val_acc: 0.6330 - val_rmse_fer: 0.1195
#
# Epoch 00025: val_acc did not improve from 0.63332
# Epoch 26/200
# 503/503 [==============================] - 79s 156ms/step - loss: 1.0340 - acc: 0.6106 - rmse_fer: 0.1234 - val_loss: 0.9719 - val_acc: 0.6289 - val_rmse_fer: 0.1210
#
# Epoch 00026: val_acc did not improve from 0.63332
# Epoch 27/200
# 503/503 [==============================] - 78s 156ms/step - loss: 1.0259 - acc: 0.6145 - rmse_fer: 0.1228 - val_loss: 1.0077 - val_acc: 0.6216 - val_rmse_fer: 0.1270
#
# Epoch 00027: val_acc did not improve from 0.63332
# Epoch 28/200
# 503/503 [==============================] - 78s 156ms/step - loss: 1.0219 - acc: 0.6146 - rmse_fer: 0.1230 - val_loss: 0.9592 - val_acc: 0.6342 - val_rmse_fer: 0.1195
#
# Epoch 00028: val_acc improved from 0.63332 to 0.63416, saving model to Final_Subm_FER_Tony_v1_.best.hdf5
# Epoch 29/200
# 503/503 [==============================] - 78s 156ms/step - loss: 1.0152 - acc: 0.6173 - rmse_fer: 0.1223 - val_loss: 0.9881 - val_acc: 0.6264 - val_rmse_fer: 0.1241
#
# Epoch 00029: val_acc did not improve from 0.63416
# Epoch 30/200
# 503/503 [==============================] - 79s 156ms/step - loss: 1.0107 - acc: 0.6186 - rmse_fer: 0.1219 - val_loss: 1.0339 - val_acc: 0.6080 - val_rmse_fer: 0.1260
#
# Epoch 00030: val_acc did not improve from 0.63416
# Epoch 31/200
# 503/503 [==============================] - 78s 156ms/step - loss: 1.0043 - acc: 0.6215 - rmse_fer: 0.1217 - val_loss: 0.9372 - val_acc: 0.6450 - val_rmse_fer: 0.1173
# Epoch 00031: val_acc improved from 0.63416 to 0.64503, saving model to Final_Subm_FER_Tony_v1_.best.hdf5
# Epoch 32/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.9980 - acc: 0.6227 - rmse_fer: 0.1215 - val_loss: 0.9704 - val_acc: 0.6297 - val_rmse_fer: 0.1215
#
# Epoch 00032: val_acc did not improve from 0.64503
# Epoch 33/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.9939 - acc: 0.6258 - rmse_fer: 0.1209 - val_loss: 0.9945 - val_acc: 0.6250 - val_rmse_fer: 0.1241
#
# Epoch 00033: val_acc did not improve from 0.64503
# Epoch 34/200
# 503/503 [==============================] - 79s 156ms/step - loss: 0.9898 - acc: 0.6266 - rmse_fer: 0.1208 - val_loss: 0.9416 - val_acc: 0.6414 - val_rmse_fer: 0.1163
#
# Epoch 00034: val_acc did not improve from 0.64503
# Epoch 35/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.9802 - acc: 0.6317 - rmse_fer: 0.1201 - val_loss: 0.9419 - val_acc: 0.6456 - val_rmse_fer: 0.1183
#
# Epoch 00035: val_acc improved from 0.64503 to 0.64558, saving model to Final_Subm_FER_Tony_v1_.best.hdf5
# Epoch 36/200
# 503/503 [==============================] - 79s 156ms/step - loss: 0.9742 - acc: 0.6338 - rmse_fer: 0.1201 - val_loss: 0.9677 - val_acc: 0.6350 - val_rmse_fer: 0.1218
#
# Epoch 00036: val_acc did not improve from 0.64558
# Epoch 37/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.9714 - acc: 0.6341 - rmse_fer: 0.1196 - val_loss: 0.9480 - val_acc: 0.6434 - val_rmse_fer: 0.1186
#
# Epoch 00037: val_acc did not improve from 0.64558
# Epoch 38/200
# 503/503 [==============================] - 79s 156ms/step - loss: 0.9686 - acc: 0.6342 - rmse_fer: 0.1195 - val_loss: 0.9545 - val_acc: 0.6461 - val_rmse_fer: 0.1194
#
# Epoch 00038: val_acc improved from 0.64558 to 0.64614, saving model to Final_Subm_FER_Tony_v1_.best.hdf5
# Epoch 39/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.9637 - acc: 0.6382 - rmse_fer: 0.1194 - val_loss: 0.9539 - val_acc: 0.6358 - val_rmse_fer: 0.1229
#
# Epoch 00039: val_acc did not improve from 0.64614
# Epoch 40/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.9587 - acc: 0.6389 - rmse_fer: 0.1195 - val_loss: 0.9392 - val_acc: 0.6478 - val_rmse_fer: 0.1185
#
# Epoch 00040: val_acc improved from 0.64614 to 0.64781, saving model to Final_Subm_FER_Tony_v1_.best.hdf5
# Epoch 41/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.9556 - acc: 0.6407 - rmse_fer: 0.1187 - val_loss: 0.9682 - val_acc: 0.6347 - val_rmse_fer: 0.1206
#
# Epoch 00041: val_acc did not improve from 0.64781
# Epoch 42/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.9501 - acc: 0.6415 - rmse_fer: 0.1184 - val_loss: 0.9284 - val_acc: 0.6459 - val_rmse_fer: 0.1189
#
# Epoch 00042: val_acc did not improve from 0.64781
# Epoch 43/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.9484 - acc: 0.6432 - rmse_fer: 0.1186 - val_loss: 0.9400 - val_acc: 0.6369 - val_rmse_fer: 0.1180
#
# Epoch 00043: val_acc did not improve from 0.64781
# Epoch 44/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.9425 - acc: 0.6465 - rmse_fer: 0.1179 - val_loss: 0.9038 - val_acc: 0.6656 - val_rmse_fer: 0.1154
#
# Epoch 00044: val_acc improved from 0.64781 to 0.66565, saving model to Final_Subm_FER_Tony_v1_.best.hdf5
# Epoch 45/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.9413 - acc: 0.6467 - rmse_fer: 0.1179 - val_loss: 0.9347 - val_acc: 0.6459 - val_rmse_fer: 0.1177
#
# Epoch 00045: val_acc did not improve from 0.66565
# Epoch 46/200
# 503/503 [==============================] - 79s 156ms/step - loss: 0.9362 - acc: 0.6486 - rmse_fer: 0.1171 - val_loss: 0.9493 - val_acc: 0.6406 - val_rmse_fer: 0.1198
#
# Epoch 00046: val_acc did not improve from 0.66565
# Epoch 47/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.9275 - acc: 0.6498 - rmse_fer: 0.1170 - val_loss: 0.9390 - val_acc: 0.6484 - val_rmse_fer: 0.1222
#
# Epoch 00047: val_acc did not improve from 0.66565
# Epoch 48/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.9314 - acc: 0.6479 - rmse_fer: 0.1176 - val_loss: 0.9093 - val_acc: 0.6534 - val_rmse_fer: 0.1162
#
# Epoch 00048: val_acc did not improve from 0.66565
# Epoch 49/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.9213 - acc: 0.6535 - rmse_fer: 0.1165 - val_loss: 0.9221 - val_acc: 0.6498 - val_rmse_fer: 0.1168
#
# Epoch 00049: val_acc did not improve from 0.66565
# Epoch 50/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.9176 - acc: 0.6547 - rmse_fer: 0.1168 - val_loss: 0.9235 - val_acc: 0.6598 - val_rmse_fer: 0.1162
#
# Epoch 00050: val_acc did not improve from 0.66565
# Epoch 51/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.9141 - acc: 0.6574 - rmse_fer: 0.1164 - val_loss: 0.9153 - val_acc: 0.6545 - val_rmse_fer: 0.1167
#
# Epoch 00051: val_acc did not improve from 0.66565
# Epoch 52/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.9145 - acc: 0.6562 - rmse_fer: 0.1165 - val_loss: 0.9025 - val_acc: 0.6645 - val_rmse_fer: 0.1141
#
# Epoch 00052: val_acc did not improve from 0.66565
# Epoch 53/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.9071 - acc: 0.6590 - rmse_fer: 0.1159 - val_loss: 0.9329 - val_acc: 0.6576 - val_rmse_fer: 0.1189
#
# Epoch 00053: val_acc did not improve from 0.66565
# Epoch 54/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.9037 - acc: 0.6596 - rmse_fer: 0.1155 - val_loss: 0.9042 - val_acc: 0.6587 - val_rmse_fer: 0.1172
#
# Epoch 00054: val_acc did not improve from 0.66565
# Epoch 55/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.9022 - acc: 0.6616 - rmse_fer: 0.1156 - val_loss: 0.9091 - val_acc: 0.6556 - val_rmse_fer: 0.1170
#
# Epoch 00055: val_acc did not improve from 0.66565
# Epoch 56/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.9020 - acc: 0.6590 - rmse_fer: 0.1158 - val_loss: 0.9092 - val_acc: 0.6643 - val_rmse_fer: 0.1165
#
# Epoch 00056: val_acc did not improve from 0.66565
# Epoch 57/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.8965 - acc: 0.6629 - rmse_fer: 0.1156 - val_loss: 0.9040 - val_acc: 0.6701 - val_rmse_fer: 0.1147
#
# Epoch 00057: val_acc improved from 0.66565 to 0.67010, saving model to Final_Subm_FER_Tony_v1_.best.hdf5
# Epoch 58/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.8953 - acc: 0.6626 - rmse_fer: 0.1152 - val_loss: 0.9124 - val_acc: 0.6576 - val_rmse_fer: 0.1181
#
# Epoch 00058: val_acc did not improve from 0.67010
# Epoch 59/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.8897 - acc: 0.6670 - rmse_fer: 0.1147 - val_loss: 0.9872 - val_acc: 0.6322 - val_rmse_fer: 0.1236
#
# Epoch 00059: val_acc did not improve from 0.67010
# Epoch 60/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.8865 - acc: 0.6666 - rmse_fer: 0.1146 - val_loss: 0.9046 - val_acc: 0.6551 - val_rmse_fer: 0.1156
#
# Epoch 00060: val_acc did not improve from 0.67010
# Epoch 61/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.8850 - acc: 0.6682 - rmse_fer: 0.1145 - val_loss: 0.9299 - val_acc: 0.6709 - val_rmse_fer: 0.1177
#
# Epoch 00061: val_acc improved from 0.67010 to 0.67094, saving model to Final_Subm_FER_Tony_v1_.best.hdf5
# Epoch 62/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.8802 - acc: 0.6686 - rmse_fer: 0.1141 - val_loss: 0.8994 - val_acc: 0.6651 - val_rmse_fer: 0.1135
#
# Epoch 00062: val_acc did not improve from 0.67094
# Epoch 63/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.8753 - acc: 0.6713 - rmse_fer: 0.1139 - val_loss: 0.8968 - val_acc: 0.6609 - val_rmse_fer: 0.1142
#
# Epoch 00063: val_acc did not improve from 0.67094
# Epoch 64/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.8769 - acc: 0.6701 - rmse_fer: 0.1138 - val_loss: 0.9199 - val_acc: 0.6598 - val_rmse_fer: 0.1178
#
# Epoch 00064: val_acc did not improve from 0.67094
# Epoch 65/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.8727 - acc: 0.6719 - rmse_fer: 0.1133 - val_loss: 0.8940 - val_acc: 0.6640 - val_rmse_fer: 0.1141
# Epoch 00065: val_acc did not improve from 0.67094
# Epoch 66/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.8655 - acc: 0.6756 - rmse_fer: 0.1127 - val_loss: 0.8905 - val_acc: 0.6771 - val_rmse_fer: 0.1140
#
# Epoch 00066: val_acc improved from 0.67094 to 0.67707, saving model to Final_Subm_FER_Tony_v1_.best.hdf5
# Epoch 67/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.8696 - acc: 0.6735 - rmse_fer: 0.1129 - val_loss: 0.9114 - val_acc: 0.6581 - val_rmse_fer: 0.1167
#
# Epoch 00067: val_acc did not improve from 0.67707
# Epoch 68/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.8622 - acc: 0.6753 - rmse_fer: 0.1121 - val_loss: 0.9200 - val_acc: 0.6578 - val_rmse_fer: 0.1163
#
# Epoch 00068: val_acc did not improve from 0.67707
# Epoch 69/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.8612 - acc: 0.6771 - rmse_fer: 0.1123 - val_loss: 0.8784 - val_acc: 0.6751 - val_rmse_fer: 0.1137
#
# Epoch 00069: val_acc did not improve from 0.67707
# Epoch 70/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.8625 - acc: 0.6750 - rmse_fer: 0.1124 - val_loss: 0.9051 - val_acc: 0.6734 - val_rmse_fer: 0.1139
#
# Epoch 00070: val_acc did not improve from 0.67707
# Epoch 71/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.8586 - acc: 0.6765 - rmse_fer: 0.1122 - val_loss: 0.8908 - val_acc: 0.6718 - val_rmse_fer: 0.1139
#
# Epoch 00071: val_acc did not improve from 0.67707
# Epoch 72/200
# 503/503 [==============================] - 79s 156ms/step - loss: 0.8482 - acc: 0.6807 - rmse_fer: 0.1118 - val_loss: 0.9314 - val_acc: 0.6548 - val_rmse_fer: 0.1170
#
# Epoch 00072: val_acc did not improve from 0.67707
# Epoch 73/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.8512 - acc: 0.6777 - rmse_fer: 0.1120 - val_loss: 0.9072 - val_acc: 0.6659 - val_rmse_fer: 0.1149
#
# Epoch 00073: val_acc did not improve from 0.67707
# Epoch 74/200
# 503/503 [==============================] - 79s 156ms/step - loss: 0.8530 - acc: 0.6770 - rmse_fer: 0.1122 - val_loss: 0.9326 - val_acc: 0.6556 - val_rmse_fer: 0.1196
#
# Epoch 00074: val_acc did not improve from 0.67707
# Epoch 75/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.8449 - acc: 0.6810 - rmse_fer: 0.1117 - val_loss: 0.9032 - val_acc: 0.6604 - val_rmse_fer: 0.1156
#
# Epoch 00075: val_acc did not improve from 0.67707
# Epoch 76/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.8457 - acc: 0.6813 - rmse_fer: 0.1113 - val_loss: 0.8971 - val_acc: 0.6612 - val_rmse_fer: 0.1148
#
# Epoch 00076: val_acc did not improve from 0.67707
# Epoch 77/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.8380 - acc: 0.6844 - rmse_fer: 0.1110 - val_loss: 0.8839 - val_acc: 0.6757 - val_rmse_fer: 0.1130
#
# Epoch 00077: val_acc did not improve from 0.67707
# Epoch 78/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.8376 - acc: 0.6849 - rmse_fer: 0.1109 - val_loss: 0.8879 - val_acc: 0.6709 - val_rmse_fer: 0.1157
#
# Epoch 00078: val_acc did not improve from 0.67707
# Epoch 79/200
# 503/503 [==============================] - 79s 156ms/step - loss: 0.8384 - acc: 0.6853 - rmse_fer: 0.1109 - val_loss: 0.8792 - val_acc: 0.6812 - val_rmse_fer: 0.1109
#
# Epoch 00079: val_acc improved from 0.67707 to 0.68125, saving model to Final_Subm_FER_Tony_v1_.best.hdf5
# Epoch 80/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.8307 - acc: 0.6874 - rmse_fer: 0.1105 - val_loss: 0.8881 - val_acc: 0.6670 - val_rmse_fer: 0.1136
#
# Epoch 00080: val_acc did not improve from 0.68125
# Epoch 81/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.8262 - acc: 0.6896 - rmse_fer: 0.1102 - val_loss: 0.8917 - val_acc: 0.6762 - val_rmse_fer: 0.1166
#
# Epoch 00081: val_acc did not improve from 0.68125
# Epoch 82/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.8284 - acc: 0.6875 - rmse_fer: 0.1104 - val_loss: 0.8945 - val_acc: 0.6721 - val_rmse_fer: 0.1155
#
# Epoch 00082: val_acc did not improve from 0.68125
# Epoch 83/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.8246 - acc: 0.6896 - rmse_fer: 0.1102 - val_loss: 0.8938 - val_acc: 0.6773 - val_rmse_fer: 0.1108
#
# Epoch 00083: val_acc did not improve from 0.68125
# Epoch 84/200
# 503/503 [==============================] - 79s 156ms/step - loss: 0.8238 - acc: 0.6899 - rmse_fer: 0.1101 - val_loss: 0.9064 - val_acc: 0.6715 - val_rmse_fer: 0.1147
#
# Epoch 00084: val_acc did not improve from 0.68125
# Epoch 85/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.8168 - acc: 0.6934 - rmse_fer: 0.1097 - val_loss: 0.9109 - val_acc: 0.6787 - val_rmse_fer: 0.1153
#
# Epoch 00085: val_acc did not improve from 0.68125
# Epoch 86/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.8164 - acc: 0.6924 - rmse_fer: 0.1096 - val_loss: 0.9218 - val_acc: 0.6670 - val_rmse_fer: 0.1147
#
# Epoch 00086: val_acc did not improve from 0.68125
# Epoch 87/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.8178 - acc: 0.6922 - rmse_fer: 0.1097 - val_loss: 0.9100 - val_acc: 0.6721 - val_rmse_fer: 0.1149
#
# Epoch 00087: val_acc did not improve from 0.68125
# Epoch 88/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.8133 - acc: 0.6942 - rmse_fer: 0.1094 - val_loss: 0.8942 - val_acc: 0.6732 - val_rmse_fer: 0.1146
#
# Epoch 00088: val_acc did not improve from 0.68125
# Epoch 89/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.8090 - acc: 0.6947 - rmse_fer: 0.1089 - val_loss: 0.9046 - val_acc: 0.6757 - val_rmse_fer: 0.1125
#
# Epoch 00089: val_acc did not improve from 0.68125
# Epoch 90/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.8070 - acc: 0.6947 - rmse_fer: 0.1089 - val_loss: 0.8800 - val_acc: 0.6810 - val_rmse_fer: 0.1124
#
# Epoch 00090: val_acc did not improve from 0.68125
# Epoch 91/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.8052 - acc: 0.6964 - rmse_fer: 0.1090 - val_loss: 0.9330 - val_acc: 0.6754 - val_rmse_fer: 0.1138
#
# Epoch 00091: val_acc did not improve from 0.68125
# Epoch 92/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.8067 - acc: 0.6969 - rmse_fer: 0.1085 - val_loss: 0.8993 - val_acc: 0.6773 - val_rmse_fer: 0.1130
#
# Epoch 00092: val_acc did not improve from 0.68125
# Epoch 93/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.8041 - acc: 0.6961 - rmse_fer: 0.1083 - val_loss: 0.9023 - val_acc: 0.6768 - val_rmse_fer: 0.1146
#
# Epoch 00093: val_acc did not improve from 0.68125
# Epoch 94/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.8013 - acc: 0.6983 - rmse_fer: 0.1085 - val_loss: 0.9308 - val_acc: 0.6698 - val_rmse_fer: 0.1185
#
# Epoch 00094: val_acc did not improve from 0.68125
# Epoch 95/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.7967 - acc: 0.6995 - rmse_fer: 0.1081 - val_loss: 0.9266 - val_acc: 0.6612 - val_rmse_fer: 0.1148
#
# Epoch 00095: val_acc did not improve from 0.68125
# Epoch 96/200
# 503/503 [==============================] - 79s 156ms/step - loss: 0.7932 - acc: 0.7023 - rmse_fer: 0.1074 - val_loss: 0.8973 - val_acc: 0.6812 - val_rmse_fer: 0.1136
#
# Epoch 00096: val_acc did not improve from 0.68125
# Epoch 97/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.7909 - acc: 0.7021 - rmse_fer: 0.1071 - val_loss: 0.9248 - val_acc: 0.6654 - val_rmse_fer: 0.1155
#
# Epoch 00097: val_acc did not improve from 0.68125
# Epoch 98/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.7887 - acc: 0.7036 - rmse_fer: 0.1075 - val_loss: 0.9023 - val_acc: 0.6695 - val_rmse_fer: 0.1138
#
# Epoch 00098: val_acc did not improve from 0.68125
# Epoch 99/200
# 503/503 [==============================] - 79s 156ms/step - loss: 0.7892 - acc: 0.7011 - rmse_fer: 0.1074 - val_loss: 0.9116 - val_acc: 0.6785 - val_rmse_fer: 0.1133
#
# Epoch 00099: val_acc did not improve from 0.68125
# Epoch 100/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.7834 - acc: 0.7039 - rmse_fer: 0.1067 - val_loss: 0.9262 - val_acc: 0.6651 - val_rmse_fer: 0.1156
#
# Epoch 00100: val_acc did not improve from 0.68125
# Epoch 101/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.7847 - acc: 0.7030 - rmse_fer: 0.1070 - val_loss: 0.9132 - val_acc: 0.6682 - val_rmse_fer: 0.1131
#
# Epoch 00101: val_acc did not improve from 0.68125
# Epoch 102/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.7828 - acc: 0.7044 - rmse_fer: 0.1069 - val_loss: 0.9178 - val_acc: 0.6773 - val_rmse_fer: 0.1132
#
# Epoch 00102: val_acc did not improve from 0.68125
# Epoch 103/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.7766 - acc: 0.7067 - rmse_fer: 0.1064 - val_loss: 0.9215 - val_acc: 0.6785 - val_rmse_fer: 0.1147
#
# Epoch 00103: val_acc did not improve from 0.68125
# Epoch 104/200
# 503/503 [==============================] - 79s 156ms/step - loss: 0.7734 - acc: 0.7088 - rmse_fer: 0.1058 - val_loss: 0.9187 - val_acc: 0.6704 - val_rmse_fer: 0.1147
#
# Epoch 00104: val_acc did not improve from 0.68125
# Epoch 105/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.7758 - acc: 0.7090 - rmse_fer: 0.1062 - val_loss: 0.9095 - val_acc: 0.6762 - val_rmse_fer: 0.1141
#
# Epoch 00105: val_acc did not improve from 0.68125
# Epoch 106/200
# 503/503 [==============================] - 79s 156ms/step - loss: 0.7678 - acc: 0.7103 - rmse_fer: 0.1053 - val_loss: 0.8914 - val_acc: 0.6771 - val_rmse_fer: 0.1110
#
# Epoch 00106: val_acc did not improve from 0.68125
# Epoch 107/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.7706 - acc: 0.7091 - rmse_fer: 0.1057 - val_loss: 0.9329 - val_acc: 0.6712 - val_rmse_fer: 0.1147
#
# Epoch 00107: val_acc did not improve from 0.68125
# Epoch 108/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.7714 - acc: 0.7086 - rmse_fer: 0.1060 - val_loss: 0.9051 - val_acc: 0.6732 - val_rmse_fer: 0.1117
#
# Epoch 00108: val_acc did not improve from 0.68125
# Epoch 109/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.7665 - acc: 0.7119 - rmse_fer: 0.1054 - val_loss: 0.9257 - val_acc: 0.6760 - val_rmse_fer: 0.1137
#
# Epoch 00109: val_acc did not improve from 0.68125
# Epoch 110/200
# 503/503 [==============================] - 79s 156ms/step - loss: 0.7625 - acc: 0.7136 - rmse_fer: 0.1054 - val_loss: 0.9712 - val_acc: 0.6592 - val_rmse_fer: 0.1196
#
# Epoch 00110: val_acc did not improve from 0.68125
# Epoch 111/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.7642 - acc: 0.7115 - rmse_fer: 0.1053 - val_loss: 0.9156 - val_acc: 0.6679 - val_rmse_fer: 0.1154
#
# Epoch 00111: val_acc did not improve from 0.68125
# Epoch 112/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.7605 - acc: 0.7125 - rmse_fer: 0.1051 - val_loss: 0.9199 - val_acc: 0.6771 - val_rmse_fer: 0.1160
#
# Epoch 00112: val_acc did not improve from 0.68125
# Epoch 113/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.7549 - acc: 0.7154 - rmse_fer: 0.1046 - val_loss: 0.9120 - val_acc: 0.6793 - val_rmse_fer: 0.1141
#
# Epoch 00113: val_acc did not improve from 0.68125
# Epoch 114/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.7547 - acc: 0.7166 - rmse_fer: 0.1048 - val_loss: 0.9018 - val_acc: 0.6860 - val_rmse_fer: 0.1128
#
# Epoch 00114: val_acc improved from 0.68125 to 0.68598, saving model to Final_Subm_FER_Tony_v1_.best.hdf5
# Epoch 115/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.7524 - acc: 0.7161 - rmse_fer: 0.1047 - val_loss: 0.9401 - val_acc: 0.6693 - val_rmse_fer: 0.1155
#
# Epoch 00115: val_acc did not improve from 0.68598
# Epoch 116/200
# 503/503 [==============================] - 79s 156ms/step - loss: 0.7511 - acc: 0.7167 - rmse_fer: 0.1046 - val_loss: 0.9069 - val_acc: 0.6824 - val_rmse_fer: 0.1117
#
# Epoch 00116: val_acc did not improve from 0.68598
# Epoch 117/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.7478 - acc: 0.7176 - rmse_fer: 0.1040 - val_loss: 0.9282 - val_acc: 0.6698 - val_rmse_fer: 0.1154
#
# Epoch 00117: val_acc did not improve from 0.68598
# Epoch 118/200
# 503/503 [==============================] - 79s 156ms/step - loss: 0.7482 - acc: 0.7187 - rmse_fer: 0.1040 - val_loss: 0.9095 - val_acc: 0.6865 - val_rmse_fer: 0.1127
#
# Epoch 00118: val_acc improved from 0.68598 to 0.68654, saving model to Final_Subm_FER_Tony_v1_.best.hdf5
# Epoch 119/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.7452 - acc: 0.7189 - rmse_fer: 0.1037 - val_loss: 0.9213 - val_acc: 0.6807 - val_rmse_fer: 0.1138
#
# Epoch 00119: val_acc did not improve from 0.68654
# Epoch 120/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.7464 - acc: 0.7188 - rmse_fer: 0.1040 - val_loss: 0.9277 - val_acc: 0.6807 - val_rmse_fer: 0.1137
#
# Epoch 00120: val_acc did not improve from 0.68654
# Epoch 121/200
# 503/503 [==============================] - 79s 156ms/step - loss: 0.7406 - acc: 0.7209 - rmse_fer: 0.1035 - val_loss: 0.9200 - val_acc: 0.6779 - val_rmse_fer: 0.1130
#
# Epoch 00121: val_acc did not improve from 0.68654
# Epoch 122/200
# 503/503 [==============================] - 79s 156ms/step - loss: 0.7374 - acc: 0.7221 - rmse_fer: 0.1033 - val_loss: 0.9541 - val_acc: 0.6729 - val_rmse_fer: 0.1136
#
# Epoch 00122: val_acc did not improve from 0.68654
# Epoch 123/200
# 503/503 [==============================] - 79s 156ms/step - loss: 0.7407 - acc: 0.7218 - rmse_fer: 0.1032 - val_loss: 0.9238 - val_acc: 0.6793 - val_rmse_fer: 0.1127
#
# Epoch 00123: val_acc did not improve from 0.68654
# Epoch 124/200
# 503/503 [==============================] - 79s 156ms/step - loss: 0.7390 - acc: 0.7209 - rmse_fer: 0.1031 - val_loss: 0.9234 - val_acc: 0.6812 - val_rmse_fer: 0.1132
#
# Epoch 00124: val_acc did not improve from 0.68654
# Epoch 125/200
# 503/503 [==============================] - 79s 156ms/step - loss: 0.7341 - acc: 0.7228 - rmse_fer: 0.1028 - val_loss: 0.9158 - val_acc: 0.6849 - val_rmse_fer: 0.1118
#
# Epoch 00125: val_acc did not improve from 0.68654
# Epoch 126/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.7278 - acc: 0.7244 - rmse_fer: 0.1024 - val_loss: 0.9273 - val_acc: 0.6715 - val_rmse_fer: 0.1149
#
# Epoch 00126: val_acc did not improve from 0.68654
# Epoch 127/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.7263 - acc: 0.7258 - rmse_fer: 0.1025 - val_loss: 0.9424 - val_acc: 0.6799 - val_rmse_fer: 0.1123
#
# Epoch 00127: val_acc did not improve from 0.68654
# Epoch 128/200
# 503/503 [==============================] - 79s 156ms/step - loss: 0.7275 - acc: 0.7251 - rmse_fer: 0.1024 - val_loss: 0.9088 - val_acc: 0.6863 - val_rmse_fer: 0.1122
#
# Epoch 00128: val_acc did not improve from 0.68654
# Epoch 129/200
# 503/503 [==============================] - 79s 156ms/step - loss: 0.7214 - acc: 0.7262 - rmse_fer: 0.1019 - val_loss: 0.9448 - val_acc: 0.6801 - val_rmse_fer: 0.1134
#
# Epoch 00129: val_acc did not improve from 0.68654
# Epoch 130/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.7216 - acc: 0.7271 - rmse_fer: 0.1018 - val_loss: 0.9423 - val_acc: 0.6773 - val_rmse_fer: 0.1136
#
# Epoch 00130: val_acc did not improve from 0.68654
# Epoch 131/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.7178 - acc: 0.7272 - rmse_fer: 0.1015 - val_loss: 0.9433 - val_acc: 0.6810 - val_rmse_fer: 0.1118
#
# Epoch 00131: val_acc did not improve from 0.68654
# Epoch 132/200
# 503/503 [==============================] - 79s 156ms/step - loss: 0.7129 - acc: 0.7316 - rmse_fer: 0.1011 - val_loss: 0.9591 - val_acc: 0.6659 - val_rmse_fer: 0.1147
#
# Epoch 00132: val_acc did not improve from 0.68654
# Epoch 133/200
# 503/503 [==============================] - 79s 156ms/step - loss: 0.7213 - acc: 0.7275 - rmse_fer: 0.1017 - val_loss: 0.9605 - val_acc: 0.6718 - val_rmse_fer: 0.1141
#
# Epoch 00133: val_acc did not improve from 0.68654
# Epoch 134/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.7163 - acc: 0.7304 - rmse_fer: 0.1013 - val_loss: 0.9355 - val_acc: 0.6765 - val_rmse_fer: 0.1123
#
# Epoch 00134: val_acc did not improve from 0.68654
# Epoch 135/200
# 503/503 [==============================] - 79s 156ms/step - loss: 0.7114 - acc: 0.7320 - rmse_fer: 0.1010 - val_loss: 0.9415 - val_acc: 0.6751 - val_rmse_fer: 0.1132
#
# Epoch 00135: val_acc did not improve from 0.68654
# Epoch 136/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.7096 - acc: 0.7331 - rmse_fer: 0.1008 - val_loss: 0.9244 - val_acc: 0.6871 - val_rmse_fer: 0.1105
#
# Epoch 00136: val_acc improved from 0.68654 to 0.68710, saving model to Final_Subm_FER_Tony_v1_.best.hdf5
# Epoch 137/200
# 503/503 [==============================] - 79s 156ms/step - loss: 0.7102 - acc: 0.7316 - rmse_fer: 0.1007 - val_loss: 0.9249 - val_acc: 0.6846 - val_rmse_fer: 0.1123
#
# Epoch 00137: val_acc did not improve from 0.68710
# Epoch 138/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.7054 - acc: 0.7345 - rmse_fer: 0.1004 - val_loss: 0.9420 - val_acc: 0.6771 - val_rmse_fer: 0.1131
#
# Epoch 00138: val_acc did not improve from 0.68710
# Epoch 139/200
# 503/503 [==============================] - 79s 156ms/step - loss: 0.7063 - acc: 0.7338 - rmse_fer: 0.1008 - val_loss: 0.9452 - val_acc: 0.6812 - val_rmse_fer: 0.1136
#
# Epoch 00139: val_acc did not improve from 0.68710
# Epoch 140/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.7003 - acc: 0.7370 - rmse_fer: 0.0999 - val_loss: 0.9144 - val_acc: 0.6849 - val_rmse_fer: 0.1110
#
# Epoch 00140: val_acc did not improve from 0.68710
# Epoch 141/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.7005 - acc: 0.7355 - rmse_fer: 0.1000 - val_loss: 0.9347 - val_acc: 0.6824 - val_rmse_fer: 0.1127
#
# Epoch 00141: val_acc did not improve from 0.68710
# Epoch 142/200
# 503/503 [==============================] - 79s 156ms/step - loss: 0.7001 - acc: 0.7358 - rmse_fer: 0.1000 - val_loss: 0.9071 - val_acc: 0.6874 - val_rmse_fer: 0.1095
#
# Epoch 00142: val_acc improved from 0.68710 to 0.68738, saving model to Final_Subm_FER_Tony_v1_.best.hdf5
# Epoch 143/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6969 - acc: 0.7358 - rmse_fer: 0.0996 - val_loss: 0.9228 - val_acc: 0.6860 - val_rmse_fer: 0.1111
#
# Epoch 00143: val_acc did not improve from 0.68738
# Epoch 144/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6981 - acc: 0.7354 - rmse_fer: 0.0996 - val_loss: 0.9225 - val_acc: 0.6835 - val_rmse_fer: 0.1123
#
# Epoch 00144: val_acc did not improve from 0.68738
# Epoch 145/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6910 - acc: 0.7392 - rmse_fer: 0.0991 - val_loss: 0.9863 - val_acc: 0.6712 - val_rmse_fer: 0.1154
#
# Epoch 00145: val_acc did not improve from 0.68738
# Epoch 146/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6866 - acc: 0.7413 - rmse_fer: 0.0988 - val_loss: 0.9739 - val_acc: 0.6709 - val_rmse_fer: 0.1163
#
# Epoch 00146: val_acc did not improve from 0.68738
# Epoch 147/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6877 - acc: 0.7402 - rmse_fer: 0.0990 - val_loss: 1.0053 - val_acc: 0.6682 - val_rmse_fer: 0.1151
#
# Epoch 00147: val_acc did not improve from 0.68738
# Epoch 148/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6895 - acc: 0.7402 - rmse_fer: 0.0989 - val_loss: 0.9467 - val_acc: 0.6824 - val_rmse_fer: 0.1130
#
# Epoch 00148: val_acc did not improve from 0.68738
# Epoch 149/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6830 - acc: 0.7416 - rmse_fer: 0.0988 - val_loss: 0.9884 - val_acc: 0.6801 - val_rmse_fer: 0.1150
#
# Epoch 00149: val_acc did not improve from 0.68738
# Epoch 150/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6852 - acc: 0.7413 - rmse_fer: 0.0987 - val_loss: 1.0129 - val_acc: 0.6648 - val_rmse_fer: 0.1179
#
# Epoch 00150: val_acc did not improve from 0.68738
# Epoch 151/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6792 - acc: 0.7432 - rmse_fer: 0.0982 - val_loss: 0.9306 - val_acc: 0.6885 - val_rmse_fer: 0.1111
#
# Epoch 00151: val_acc improved from 0.68738 to 0.68849, saving model to Final_Subm_FER_Tony_v1_.best.hdf5
# Epoch 152/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6783 - acc: 0.7424 - rmse_fer: 0.0979 - val_loss: 0.9850 - val_acc: 0.6762 - val_rmse_fer: 0.1139
#
# Epoch 00152: val_acc did not improve from 0.68849
# Epoch 153/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6812 - acc: 0.7437 - rmse_fer: 0.0982 - val_loss: 0.9816 - val_acc: 0.6751 - val_rmse_fer: 0.1144
#
# Epoch 00153: val_acc did not improve from 0.68849
# Epoch 154/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6751 - acc: 0.7450 - rmse_fer: 0.0978 - val_loss: 0.9759 - val_acc: 0.6796 - val_rmse_fer: 0.1133
#
# Epoch 00154: val_acc did not improve from 0.68849
# Epoch 155/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6742 - acc: 0.7454 - rmse_fer: 0.0977 - val_loss: 0.9762 - val_acc: 0.6751 - val_rmse_fer: 0.1145
#
# Epoch 00155: val_acc did not improve from 0.68849
# Epoch 156/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6698 - acc: 0.7451 - rmse_fer: 0.0976 - val_loss: 0.9972 - val_acc: 0.6704 - val_rmse_fer: 0.1163
#
# Epoch 00156: val_acc did not improve from 0.68849
# Epoch 157/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6694 - acc: 0.7467 - rmse_fer: 0.0976 - val_loss: 0.9381 - val_acc: 0.6935 - val_rmse_fer: 0.1103
#
# Epoch 00157: val_acc improved from 0.68849 to 0.69351, saving model to Final_Subm_FER_Tony_v1_.best.hdf5
# Epoch 158/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6678 - acc: 0.7468 - rmse_fer: 0.0974 - val_loss: 0.9799 - val_acc: 0.6924 - val_rmse_fer: 0.1126
#
# Epoch 00158: val_acc did not improve from 0.69351
# Epoch 159/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6676 - acc: 0.7496 - rmse_fer: 0.0970 - val_loss: 0.9779 - val_acc: 0.6826 - val_rmse_fer: 0.1120
#
# Epoch 00159: val_acc did not improve from 0.69351
# Epoch 160/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6629 - acc: 0.7507 - rmse_fer: 0.0965 - val_loss: 0.9775 - val_acc: 0.6885 - val_rmse_fer: 0.1137
#
# Epoch 00160: val_acc did not improve from 0.69351
# Epoch 161/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6652 - acc: 0.7474 - rmse_fer: 0.0969 - val_loss: 0.9645 - val_acc: 0.6849 - val_rmse_fer: 0.1120
#
# Epoch 00161: val_acc did not improve from 0.69351
# Epoch 162/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6631 - acc: 0.7497 - rmse_fer: 0.0967 - val_loss: 0.9786 - val_acc: 0.6857 - val_rmse_fer: 0.1113
#
# Epoch 00162: val_acc did not improve from 0.69351
# Epoch 163/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6582 - acc: 0.7527 - rmse_fer: 0.0960 - val_loss: 0.9551 - val_acc: 0.6918 - val_rmse_fer: 0.1105
#
# Epoch 00163: val_acc did not improve from 0.69351
# Epoch 164/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6578 - acc: 0.7522 - rmse_fer: 0.0960 - val_loss: 0.9859 - val_acc: 0.6815 - val_rmse_fer: 0.1140
#
# Epoch 00164: val_acc did not improve from 0.69351
# Epoch 165/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6578 - acc: 0.7513 - rmse_fer: 0.0961 - val_loss: 0.9773 - val_acc: 0.6799 - val_rmse_fer: 0.1125
#
# Epoch 00165: val_acc did not improve from 0.69351
# Epoch 166/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6507 - acc: 0.7534 - rmse_fer: 0.0958 - val_loss: 0.9629 - val_acc: 0.6893 - val_rmse_fer: 0.1114
#
# Epoch 00166: val_acc did not improve from 0.69351
# Epoch 167/200
# 503/503 [==============================] - 79s 156ms/step - loss: 0.6514 - acc: 0.7534 - rmse_fer: 0.0957 - val_loss: 0.9805 - val_acc: 0.6930 - val_rmse_fer: 0.1095
#
# Epoch 00167: val_acc did not improve from 0.69351
# Epoch 168/200
# 503/503 [==============================] - 79s 157ms/step - loss: 0.6439 - acc: 0.7574 - rmse_fer: 0.0948 - val_loss: 0.9825 - val_acc: 0.6871 - val_rmse_fer: 0.1119
#
# Epoch 00168: val_acc did not improve from 0.69351
# Epoch 169/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6487 - acc: 0.7555 - rmse_fer: 0.0954 - val_loss: 1.0002 - val_acc: 0.6821 - val_rmse_fer: 0.1134
#
# Epoch 00169: val_acc did not improve from 0.69351
# Epoch 170/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6498 - acc: 0.7559 - rmse_fer: 0.0954 - val_loss: 0.9790 - val_acc: 0.6746 - val_rmse_fer: 0.1134
# Epoch 00170: val_acc did not improve from 0.69351
# Epoch 171/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6473 - acc: 0.7567 - rmse_fer: 0.0953 - val_loss: 0.9447 - val_acc: 0.6877 - val_rmse_fer: 0.1101
#
# Epoch 00171: val_acc did not improve from 0.69351
# Epoch 172/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6387 - acc: 0.7583 - rmse_fer: 0.0948 - val_loss: 0.9909 - val_acc: 0.6799 - val_rmse_fer: 0.1130
#
# Epoch 00172: val_acc did not improve from 0.69351
# Epoch 173/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6395 - acc: 0.7576 - rmse_fer: 0.0947 - val_loss: 0.9848 - val_acc: 0.6812 - val_rmse_fer: 0.1137
#
# Epoch 00173: val_acc did not improve from 0.69351
# Epoch 174/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6431 - acc: 0.7578 - rmse_fer: 0.0948 - val_loss: 0.9698 - val_acc: 0.6818 - val_rmse_fer: 0.1130
#
# Epoch 00174: val_acc did not improve from 0.69351
# Epoch 175/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6397 - acc: 0.7587 - rmse_fer: 0.0948 - val_loss: 0.9825 - val_acc: 0.6773 - val_rmse_fer: 0.1144
#
# Epoch 00175: val_acc did not improve from 0.69351
# Epoch 176/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6311 - acc: 0.7636 - rmse_fer: 0.0937 - val_loss: 0.9883 - val_acc: 0.6882 - val_rmse_fer: 0.1129
#
# Epoch 00176: val_acc did not improve from 0.69351
# Epoch 177/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6327 - acc: 0.7617 - rmse_fer: 0.0938 - val_loss: 0.9688 - val_acc: 0.6882 - val_rmse_fer: 0.1119
#
# Epoch 00177: val_acc did not improve from 0.69351
# Epoch 178/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6278 - acc: 0.7645 - rmse_fer: 0.0932 - val_loss: 1.0061 - val_acc: 0.6754 - val_rmse_fer: 0.1134
#
# Epoch 00178: val_acc did not improve from 0.69351
# Epoch 179/200
# 503/503 [==============================] - 79s 156ms/step - loss: 0.6284 - acc: 0.7626 - rmse_fer: 0.0934 - val_loss: 1.0187 - val_acc: 0.6748 - val_rmse_fer: 0.1137
#
# Epoch 00179: val_acc did not improve from 0.69351
# Epoch 180/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6241 - acc: 0.7641 - rmse_fer: 0.0927 - val_loss: 0.9877 - val_acc: 0.6902 - val_rmse_fer: 0.1128
#
# Epoch 00180: val_acc did not improve from 0.69351
# Epoch 181/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6303 - acc: 0.7622 - rmse_fer: 0.0937 - val_loss: 0.9815 - val_acc: 0.6846 - val_rmse_fer: 0.1125
#
# Epoch 00181: val_acc did not improve from 0.69351
# Epoch 182/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6227 - acc: 0.7661 - rmse_fer: 0.0925 - val_loss: 1.0396 - val_acc: 0.6682 - val_rmse_fer: 0.1163
#
# Epoch 00182: val_acc did not improve from 0.69351
# Epoch 183/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6234 - acc: 0.7652 - rmse_fer: 0.0928 - val_loss: 1.0070 - val_acc: 0.6801 - val_rmse_fer: 0.1130
#
# Epoch 00183: val_acc did not improve from 0.69351
# Epoch 184/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6228 - acc: 0.7649 - rmse_fer: 0.0929 - val_loss: 0.9856 - val_acc: 0.6868 - val_rmse_fer: 0.1115
#
# Epoch 00184: val_acc did not improve from 0.69351
# Epoch 185/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6161 - acc: 0.7698 - rmse_fer: 0.0921 - val_loss: 0.9866 - val_acc: 0.6868 - val_rmse_fer: 0.1120
#
# Epoch 00185: val_acc did not improve from 0.69351
# Epoch 186/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6146 - acc: 0.7673 - rmse_fer: 0.0922 - val_loss: 1.0207 - val_acc: 0.6835 - val_rmse_fer: 0.1130
#
# Epoch 00186: val_acc did not improve from 0.69351
# Epoch 187/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6169 - acc: 0.7652 - rmse_fer: 0.0923 - val_loss: 1.0372 - val_acc: 0.6807 - val_rmse_fer: 0.1134
#
# Epoch 00187: val_acc did not improve from 0.69351
# Epoch 188/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6101 - acc: 0.7700 - rmse_fer: 0.0917 - val_loss: 1.0184 - val_acc: 0.6826 - val_rmse_fer: 0.1129
#
# Epoch 00188: val_acc did not improve from 0.69351
# Epoch 189/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6122 - acc: 0.7690 - rmse_fer: 0.0917 - val_loss: 1.0663 - val_acc: 0.6651 - val_rmse_fer: 0.1174
#
# Epoch 00189: val_acc did not improve from 0.69351
# Epoch 190/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6150 - acc: 0.7674 - rmse_fer: 0.0921 - val_loss: 1.0034 - val_acc: 0.6890 - val_rmse_fer: 0.1111
#
# Epoch 00190: val_acc did not improve from 0.69351
# Epoch 191/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6057 - acc: 0.7710 - rmse_fer: 0.0913 - val_loss: 1.0160 - val_acc: 0.6865 - val_rmse_fer: 0.1112
#
# Epoch 00191: val_acc did not improve from 0.69351
# Epoch 192/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6050 - acc: 0.7721 - rmse_fer: 0.0913 - val_loss: 1.0498 - val_acc: 0.6734 - val_rmse_fer: 0.1148
#
# Epoch 00192: val_acc did not improve from 0.69351
# Epoch 193/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6016 - acc: 0.7751 - rmse_fer: 0.0907 - val_loss: 0.9965 - val_acc: 0.6924 - val_rmse_fer: 0.1127
#
# Epoch 00193: val_acc did not improve from 0.69351
# Epoch 194/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.6041 - acc: 0.7702 - rmse_fer: 0.0914 - val_loss: 1.0087 - val_acc: 0.6826 - val_rmse_fer: 0.1127
#
# Epoch 00194: val_acc did not improve from 0.69351
# Epoch 195/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.5966 - acc: 0.7741 - rmse_fer: 0.0906 - val_loss: 0.9998 - val_acc: 0.6916 - val_rmse_fer: 0.1117
#
# Epoch 00195: val_acc did not improve from 0.69351
# Epoch 196/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.5936 - acc: 0.7741 - rmse_fer: 0.0901 - val_loss: 1.0148 - val_acc: 0.6938 - val_rmse_fer: 0.1104
#
# Epoch 00196: val_acc improved from 0.69351 to 0.69379, saving model to Final_Subm_FER_Tony_v1_.best.hdf5
# Epoch 197/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.5926 - acc: 0.7761 - rmse_fer: 0.0898 - val_loss: 1.0207 - val_acc: 0.6835 - val_rmse_fer: 0.1129
#
# Epoch 00197: val_acc did not improve from 0.69379
# Epoch 198/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.5954 - acc: 0.7753 - rmse_fer: 0.0901 - val_loss: 1.0499 - val_acc: 0.6782 - val_rmse_fer: 0.1150
#
# Epoch 00198: val_acc did not improve from 0.69379
# Epoch 199/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.5913 - acc: 0.7759 - rmse_fer: 0.0895 - val_loss: 1.0171 - val_acc: 0.6785 - val_rmse_fer: 0.1133
#
# Epoch 00199: val_acc did not improve from 0.69379
# Epoch 200/200
# 503/503 [==============================] - 78s 156ms/step - loss: 0.5897 - acc: 0.7767 - rmse_fer: 0.0895 - val_loss: 1.0120 - val_acc: 0.6885 - val_rmse_fer: 0.1110
#
# Epoch 00200: val_acc did not improve from 0.69379

# %% [markdown]
# ## 7. Evaluate the model's performance on Private Leader Board data

# %% [markdown]
# ### 7. 1 Load the trained model

# %%
filepath = "Final_Subm_FER_Tony_v1_" + r".best.hdf5"
model = load_model(filepath, custom_objects={'rmse_fer': rmse_fer})
# Out:
# WARNING:tensorflow:Variable *= will be deprecated. Use variable.assign_mul if you want assignment to the variable value or 'x = x * y' if you want a new python Tensor object.

# %% [markdown]
# ### 7.2 Verfiy the performace on train and validation data (just for confromation)

# %%
score = model.evaluate(X_train, Y_train, verbose=1)
print('Training loss:', score[0])
print('Training accuracy:', score[1])
# Out:
# 64362/64362 [==============================] - 37s 569us/step
# Training loss: 0.36501555288746657
# Training accuracy: 0.8630558404045743

# %%
score = model.evaluate(X_val, Y_val, verbose=1)
print('Public Leader Board Test loss:', score[0])
print('Public Leader Board Test accuracy:', score[1])
# Out:
# 3589/3589 [==============================] - 2s 559us/step
# Public Leader Board Test loss: 1.0147971654293695
# Public Leader Board Test accuracy: 0.6937865700752298

# %% [markdown]
# ### 7.3 Test on Private Leader Board data

# %%
#score = new_model.evaluate(X_private_test, Y_private_test, verbose=1)
score = model.evaluate(X_private_test, Y_private_test, verbose=1)
print('Private Leader Board Test loss:', score[0])
print('Private Leader Board Test accuracy:', score[1])
# Out:
# 3589/3589 [==============================] - 2s 556us/step
# Private Leader Board Test loss: 1.0147971654293695
# Private Leader Board Test accuracy: 0.6937865700752298

# %% [markdown]
# #### Record the performance metrics

# %%
ModelPerformance.loc[len(ModelPerformance)] = ['CNN model', score[1]]

# %% [markdown]
# ## 8.  Analyse the results of the stand alone model

# %% [markdown]
# ### 8.1  plot confusion matrix - check how the model performed on various classes (Training,Validation and Testing)

# %%
Y_train_pred = model.predict_proba(X_train)
Y_val_pred   = model.predict_proba(X_val)
Y_test_pred  = model.predict_proba(X_private_test)

# %%
y_true_train = []
y_pred_train = []

for row in Y_train:
    a = numpy.argmax(row) #return the indices of the maximum values along the axis
    y_true_train.append(a)
    
for row in Y_train_pred:
    a = numpy.argmax(row) #return tY_train_predhe indices of the maximum values along the axis
    y_pred_train.append(a)

# %%
y_true_val = []
y_pred_val = []

for row in Y_val:
    a = numpy.argmax(row) #return the indices of the maximum values along the axis
    y_true_val.append(a)
    
for row in Y_val_pred:
    a = numpy.argmax(row) #return tY_train_predhe indices of the maximum values along the axis
    y_pred_val.append(a)

# %%
y_true_test = []
y_pred_test = []

for row in Y_private_test:
    a = numpy.argmax(row) #return the indices of the maximum values along the axis
    y_true_test.append(a)
    
for row in Y_test_pred:
    a = numpy.argmax(row) #return tY_train_predhe indices of the maximum values along the axis
    y_pred_test.append(a)

# %%
cnf_matrix_train     = confusion_matrix(y_true_train, y_pred_train)
cnf_matrix_val       = confusion_matrix(y_true_val, y_pred_val)
cnf_matrix_test      = confusion_matrix(y_true_test, y_pred_test)

# %%
plt.figure()
plot_confusion_matrix(cnf_matrix_train, classes=Facial_Expressions, normalize=True,
                      title='Normalized confusion matrix for Training Data')

plt.figure()
plot_confusion_matrix(cnf_matrix_val, classes=Facial_Expressions, normalize=True,
                      title='Normalized confusion matrix for Validation Data')

plt.figure()
plot_confusion_matrix(cnf_matrix_test, classes=Facial_Expressions, normalize=True,
                      title='Normalized confusion matrix for Testing Data')
# Out:
# Normalized confusion matrix
# Normalized confusion matrix
# Normalized confusion matrix

# %% [markdown]
# ### 8.2  Observations
#
# - Here we can see on what classes the model performed well and bad
# - Fear and Neutral classes are performing badly on Validation Data
# - Validation and Testing matrices are exactly same (In other trials also it was observed that Validation and Testing performance were very close)

# %% [markdown]
# # 9. Build Different ensemble models to further  increase accuracy

# %% [markdown]
# ## 9.1 Simple Average Ensembling (using perturbed input)
#
# - The intution here is simple, instead of relying of a single model we rely on multiple models.
# - We perturb the input image in **8** different(one of the perturbation is doing nothing, so we pass the orginal image) ways and feed it to same **CNN** model. Output probality of the ensemble model for an image is the average of **8**  different outputs of the **CNN** model for the same imge.

# %% [markdown]
# #### Load Testing data again
# predict_prob to work we need input images in 48x48 format. So we load them again.

# %%
private_set_x, private_set_y = HelperDataProcessing.load_test_data()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: Non-string object detected for the array ordering. Please pass in 'C', 'F', 'A', or 'K' instead
#   """

# %%
proba0 = predict_prob(0, private_set_x, model)
proba1 = predict_prob(1, private_set_x, model)
proba2 = predict_prob(2, private_set_x, model)
proba3 = predict_prob(3, private_set_x, model)
proba4 = predict_prob(4, private_set_x, model)
proba5 = predict_prob(5, private_set_x, model)
proba6 = predict_prob(6, private_set_x, model)
proba7 = predict_prob(7, private_set_x, model)

# %%
Y_SA_Ense_pred = []
for row in zip(proba0,proba1,proba2,proba3,proba4,proba5,proba6,proba7):
    a = numpy.argmax(np.array(row).mean(axis=0)) #return the indices of the maximum values along the axis
    Y_SA_Ense_pred.append(a)

# %%
Y_SA_Ense_pred = np.array(Y_SA_Ense_pred)
private_set_y  = np.array(private_set_y)

# %% [markdown]
# ### Calculate how many correct predictions we got

# %%
count_correct = np.sum(Y_SA_Ense_pred == private_set_y)

# %%
Y_SA_Ense_accuracy = (float(count_correct)/len(Y_SA_Ense_pred))

# %%
print("Accuracy of Simple Average Ensembling Method on Private Leader Board Data:"+str(Y_SA_Ense_accuracy))
# Out:
# Accuracy of Simple Average Ensembling Method on Private Leader Board Data:0.7015881861242687

# %% [markdown]
# #### Record the performace metrics

# %%
ModelPerformance.loc[len(ModelPerformance)] = ['SA Ensembling +  CNN', Y_SA_Ense_accuracy]

# %%
cnf_matrix_SA_ense     = confusion_matrix(Y_SA_Ense_pred, private_set_y)

plt.figure()
plot_confusion_matrix(cnf_matrix_SA_ense, classes=Facial_Expressions, normalize=True,
                      title='Test Data - Using Simple Average Ensembling ')
# Out:
# Normalized confusion matrix

# %% [markdown]
# ### 9.1.1 Simple Average Ensembling - Observations
#
# - Using Simple Average Ensembling, we could  slightly improve the performace of the prediction model
#     - from **0.6937** to **0.7015**

# %% [markdown]
# ## 9.2 Optimal Hinge Loss Ensembling

# %% [markdown]
# ### Prepare the train test and validation data for ensembling NN

# %% [markdown]
# #### Load Training and Validation data again
# predict_prob to work we need input images in 48x48 format. So we load training and validation again.

# %%
X_train, y_train, X_val, y_val  = HelperDataProcessing.load_data()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: Non-string object detected for the array ordering. Please pass in 'C', 'F', 'A', or 'K' instead
#   """

# %%
X_test, y_test = HelperDataProcessing.load_test_data()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: Non-string object detected for the array ordering. Please pass in 'C', 'F', 'A', or 'K' instead
#   """

# %%
print(type(X_train), len(X_train), type(X_val), len(X_val), type(X_test), len(X_test))
# Out:
# <class 'list'> 32181 <class 'list'> 3589 <class 'list'> 3589

# %%
X_train_t = [np.array(x).reshape(48,48) for x in X_train]
Y_train_t = np_utils.to_categorical(y_train, 7)
X_val_t   = [np.array(x).reshape(48,48) for x in X_val]
Y_val_t   = np_utils.to_categorical(y_val, 7)
Y_test_t   = np_utils.to_categorical(y_test, 7)

# %%
type(X_train_t), len(X_train_t),type(Y_train_t), len(Y_train_t)
# Out:
# (list, 32181, numpy.ndarray, 32181)

# %%
type(X_val_t), len(X_val_t),type(Y_val_t), len(Y_val_t)
# Out:
# (list, 3589, numpy.ndarray, 3589)

# %%
type(X_val_t), len(X_val_t),type(Y_val_t), len(Y_val_t)
# Out:
# (list, 3589, numpy.ndarray, 3589)

# %%
proba0 = predict_prob(0, X_train_t, model)
proba1 = predict_prob(1, X_train_t, model)
proba2 = predict_prob(2, X_train_t, model)
proba3 = predict_prob(3, X_train_t, model)
proba4 = predict_prob(4, X_train_t, model)
proba5 = predict_prob(5, X_train_t, model)
proba6 = predict_prob(6, X_train_t, model)
proba7 = predict_prob(7, X_train_t, model)

# %%
proba0_val = predict_prob(0, X_val_t, model)
proba1_val = predict_prob(1, X_val_t, model)
proba2_val = predict_prob(2, X_val_t, model)
proba3_val = predict_prob(3, X_val_t, model)
proba4_val = predict_prob(4, X_val_t, model)
proba5_val = predict_prob(5, X_val_t, model)
proba6_val = predict_prob(6, X_val_t, model)
proba7_val = predict_prob(7, X_val_t, model)

# %%
proba0_y = predict_prob(0, private_set_x, model)
proba1_y = predict_prob(1, private_set_x, model)
proba2_y = predict_prob(2, private_set_x, model)
proba3_y = predict_prob(3, private_set_x, model)
proba4_y = predict_prob(4, private_set_x, model)
proba5_y = predict_prob(5, private_set_x, model)
proba6_y = predict_prob(6, private_set_x, model)
proba7_y = predict_prob(7, private_set_x, model)

# %%
x_train_ensemble = []
for row in zip(proba0,proba1,proba2,proba3,proba4,proba5,proba6,proba7):
    x_train_ensemble.append(row)
    
x_val_ensemble = []
for row in zip(proba0_val,proba1_val,proba2_val,proba3_val,proba4_val,proba5_val,proba6_val,proba7_val):
    x_val_ensemble.append(row)
    
x_test_ensemble = []
for row in zip(proba0_y,proba1_y,proba2_y,proba3_y,proba4_y,proba5_y,proba6_y,proba7_y):
    x_test_ensemble.append(row)

# %%
x_train_ensemble = np.array(x_train_ensemble)
x_val_ensemble   = np.array(x_val_ensemble)
x_test_ensemble  = np.array(x_test_ensemble)

# %%
x_train_ensemble = x_train_ensemble.reshape(32181, 56, 1)
x_val_ensemble   = x_val_ensemble.reshape(3589, 56, 1)
x_test_ensemble  = x_test_ensemble.reshape(3589, 56, 1)

# %%
x_train_ensemble.shape, Y_train_t.shape, x_val_ensemble.shape, Y_val_t.shape, x_test_ensemble.shape, Y_test_t.shape
# Out:
# ((32181, 56, 1),
#  (32181, 7),
#  (3589, 56, 1),
#  (3589, 7),
#  (3589, 56, 1),
#  (3589, 7))

# %% [markdown]
# ####  Define all the callback functions for the ensembling NN  model here

# %%
#Callback for saving the best ensembling NN model

filepath = file_prefix + r"ensemble_hinge.best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# %% [markdown]
# #### Define the ensembling NN model

# %%
def ensemble_model_generate():
    nb_classes, nb_peturbations = 7, 8

    model = Sequential()
    model.add(Flatten(input_shape=(nb_classes* nb_peturbations, 1)))
    model.add(Activation('relu'))
    model.add(Dense(1024))
    model.add(Activation('relu'))
    model.add(Dense(1024))
    model.add(Activation('relu'))
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dense(7))
    model.add(Activation('softmax'))

    #adam = keras.optimizers.Adam(lr=0.01, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
    sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
    #categorical_hinge, squared_hinge, mean_squared_error,sparse_categorical_crossentropy
    model.compile(loss='categorical_hinge',
    optimizer=sgd,
    metrics=['accuracy'])
    model.summary()
    return model

# %%
try:
    del ensemble_model # does model exist in the current namespace
except NameError:
    pass


ensemble_model = ensemble_model_generate()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_2 (Flatten)          (None, 56)                0
# _________________________________________________________________
# activation_11 (Activation)   (None, 56)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1024)              58368
# _________________________________________________________________
# activation_12 (Activation)   (None, 1024)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# activation_13 (Activation)   (None, 1024)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               524800
# _________________________________________________________________
# activation_14 (Activation)   (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 7)                 3591
# _________________________________________________________________
# activation_15 (Activation)   (None, 7)                 0
# =================================================================
# Total params: 1,636,359
# Trainable params: 1,636,359
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Train the ensembling NN

# %%
callbacks_list = [checkpoint]

# %%
ensemble_model.fit(x_train_ensemble, Y_train_t,
          batch_size=128,
          epochs=120,
          verbose=1,
          class_weight=class_weights,
          validation_data=(x_val_ensemble, Y_val_t),
          callbacks=callbacks_list)
# Out:
# Train on 32181 samples, validate on 3589 samples
# Epoch 1/120
# 32181/32181 [==============================] - 2s 53us/step - loss: 0.5103 - acc: 0.8321 - val_loss: 0.5887 - val_acc: 0.6941
#
# Epoch 00001: val_acc improved from -inf to 0.69407, saving model to Final_Subm_FER_Tony_v1_ensemble_hinge.best.hdf5
# Epoch 2/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2680 - acc: 0.8631 - val_loss: 0.5864 - val_acc: 0.6946
#
# Epoch 00002: val_acc improved from 0.69407 to 0.69462, saving model to Final_Subm_FER_Tony_v1_ensemble_hinge.best.hdf5
# Epoch 3/120
# 32181/32181 [==============================] - 1s 43us/step - loss: 0.2558 - acc: 0.8766 - val_loss: 0.5793 - val_acc: 0.7038
#
# Epoch 00003: val_acc improved from 0.69462 to 0.70382, saving model to Final_Subm_FER_Tony_v1_ensemble_hinge.best.hdf5
# Epoch 4/120
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.2454 - acc: 0.8790 - val_loss: 0.5783 - val_acc: 0.7041
#
# Epoch 00004: val_acc improved from 0.70382 to 0.70410, saving model to Final_Subm_FER_Tony_v1_ensemble_hinge.best.hdf5
# Epoch 5/120
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.2420 - acc: 0.8800 - val_loss: 0.5812 - val_acc: 0.7027
#
# Epoch 00005: val_acc did not improve from 0.70410
# Epoch 6/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2404 - acc: 0.8804 - val_loss: 0.5787 - val_acc: 0.7058
#
# Epoch 00006: val_acc improved from 0.70410 to 0.70577, saving model to Final_Subm_FER_Tony_v1_ensemble_hinge.best.hdf5
# Epoch 7/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2390 - acc: 0.8809 - val_loss: 0.5820 - val_acc: 0.7027
#
# Epoch 00007: val_acc did not improve from 0.70577
# Epoch 8/120
# 32181/32181 [==============================] - 1s 40us/step - loss: 0.2375 - acc: 0.8818 - val_loss: 0.5767 - val_acc: 0.7069
#
# Epoch 00008: val_acc improved from 0.70577 to 0.70688, saving model to Final_Subm_FER_Tony_v1_ensemble_hinge.best.hdf5
# Epoch 9/120
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.2376 - acc: 0.8818 - val_loss: 0.5793 - val_acc: 0.7052
#
# Epoch 00009: val_acc did not improve from 0.70688
# Epoch 10/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2367 - acc: 0.8817 - val_loss: 0.5833 - val_acc: 0.7035
#
# Epoch 00010: val_acc did not improve from 0.70688
# Epoch 11/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2360 - acc: 0.8821 - val_loss: 0.5808 - val_acc: 0.7047
#
# Epoch 00011: val_acc did not improve from 0.70688
# Epoch 12/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2345 - acc: 0.8831 - val_loss: 0.5835 - val_acc: 0.7005
#
# Epoch 00012: val_acc did not improve from 0.70688
# Epoch 13/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2344 - acc: 0.8829 - val_loss: 0.5835 - val_acc: 0.7010
#
# Epoch 00013: val_acc did not improve from 0.70688
# Epoch 14/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2339 - acc: 0.8839 - val_loss: 0.5846 - val_acc: 0.7024
#
# Epoch 00014: val_acc did not improve from 0.70688
# Epoch 15/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2337 - acc: 0.8833 - val_loss: 0.5826 - val_acc: 0.7035
#
# Epoch 00015: val_acc did not improve from 0.70688
# Epoch 16/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2328 - acc: 0.8837 - val_loss: 0.5885 - val_acc: 0.6994
#
# Epoch 00016: val_acc did not improve from 0.70688
# Epoch 17/120
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.2329 - acc: 0.8837 - val_loss: 0.5841 - val_acc: 0.7016
#
# Epoch 00017: val_acc did not improve from 0.70688
# Epoch 18/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2321 - acc: 0.8848 - val_loss: 0.5833 - val_acc: 0.7041
#
# Epoch 00018: val_acc did not improve from 0.70688
# Epoch 19/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2319 - acc: 0.8839 - val_loss: 0.5834 - val_acc: 0.7044
#
# Epoch 00019: val_acc did not improve from 0.70688
# Epoch 20/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2311 - acc: 0.8852 - val_loss: 0.5842 - val_acc: 0.7041
#
# Epoch 00020: val_acc did not improve from 0.70688
# Epoch 21/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2304 - acc: 0.8852 - val_loss: 0.5892 - val_acc: 0.6985
#
# Epoch 00021: val_acc did not improve from 0.70688
# Epoch 22/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2311 - acc: 0.8849 - val_loss: 0.5813 - val_acc: 0.7066
#
# Epoch 00022: val_acc did not improve from 0.70688
# Epoch 23/120
# 32181/32181 [==============================] - 1s 40us/step - loss: 0.2301 - acc: 0.8856 - val_loss: 0.5855 - val_acc: 0.7030
#
# Epoch 00023: val_acc did not improve from 0.70688
# Epoch 24/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2306 - acc: 0.8847 - val_loss: 0.5820 - val_acc: 0.7063
#
# Epoch 00024: val_acc did not improve from 0.70688
# Epoch 25/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2295 - acc: 0.8858 - val_loss: 0.5918 - val_acc: 0.6994
#
# Epoch 00025: val_acc did not improve from 0.70688
# Epoch 26/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2299 - acc: 0.8857 - val_loss: 0.5882 - val_acc: 0.7013
#
# Epoch 00026: val_acc did not improve from 0.70688
# Epoch 27/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2296 - acc: 0.8855 - val_loss: 0.5873 - val_acc: 0.7027
#
# Epoch 00027: val_acc did not improve from 0.70688
# Epoch 28/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2291 - acc: 0.8857 - val_loss: 0.5867 - val_acc: 0.7027
#
# Epoch 00028: val_acc did not improve from 0.70688
# Epoch 29/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2288 - acc: 0.8860 - val_loss: 0.5869 - val_acc: 0.7013
#
# Epoch 00029: val_acc did not improve from 0.70688
# Epoch 30/120
# 32181/32181 [==============================] - 1s 40us/step - loss: 0.2288 - acc: 0.8861 - val_loss: 0.5924 - val_acc: 0.6994
#
# Epoch 00030: val_acc did not improve from 0.70688
# Epoch 31/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2290 - acc: 0.8865 - val_loss: 0.5873 - val_acc: 0.7030
#
# Epoch 00031: val_acc did not improve from 0.70688
# Epoch 32/120
# 32181/32181 [==============================] - 1s 40us/step - loss: 0.2283 - acc: 0.8862 - val_loss: 0.5866 - val_acc: 0.7044
#
# Epoch 00032: val_acc did not improve from 0.70688
# Epoch 33/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2281 - acc: 0.8863 - val_loss: 0.5869 - val_acc: 0.7038
#
# Epoch 00033: val_acc did not improve from 0.70688
# Epoch 34/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2279 - acc: 0.8865 - val_loss: 0.5856 - val_acc: 0.7041
#
# Epoch 00034: val_acc did not improve from 0.70688
# Epoch 35/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2268 - acc: 0.8874 - val_loss: 0.5937 - val_acc: 0.6996
#
# Epoch 00035: val_acc did not improve from 0.70688
# Epoch 36/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2277 - acc: 0.8868 - val_loss: 0.5870 - val_acc: 0.7035
#
# Epoch 00036: val_acc did not improve from 0.70688
# Epoch 37/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2274 - acc: 0.8867 - val_loss: 0.5891 - val_acc: 0.7013
#
# Epoch 00037: val_acc did not improve from 0.70688
# Epoch 38/120
# 32181/32181 [==============================] - 1s 40us/step - loss: 0.2269 - acc: 0.8871 - val_loss: 0.5934 - val_acc: 0.6991
#
# Epoch 00038: val_acc did not improve from 0.70688
# Epoch 39/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2263 - acc: 0.8872 - val_loss: 0.5878 - val_acc: 0.7019
#
# Epoch 00039: val_acc did not improve from 0.70688
# Epoch 40/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2263 - acc: 0.8878 - val_loss: 0.5878 - val_acc: 0.7019
#
# Epoch 00040: val_acc did not improve from 0.70688
# Epoch 41/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2268 - acc: 0.8875 - val_loss: 0.5918 - val_acc: 0.6988
#
# Epoch 00041: val_acc did not improve from 0.70688
# Epoch 42/120
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.2263 - acc: 0.8876 - val_loss: 0.5923 - val_acc: 0.7002
#
# Epoch 00042: val_acc did not improve from 0.70688
# Epoch 43/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2258 - acc: 0.8877 - val_loss: 0.5890 - val_acc: 0.7013
#
# Epoch 00043: val_acc did not improve from 0.70688
# Epoch 44/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2258 - acc: 0.8877 - val_loss: 0.5932 - val_acc: 0.6996
#
# Epoch 00044: val_acc did not improve from 0.70688
# Epoch 45/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2253 - acc: 0.8885 - val_loss: 0.5924 - val_acc: 0.7010
#
# Epoch 00045: val_acc did not improve from 0.70688
# Epoch 46/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2250 - acc: 0.8883 - val_loss: 0.6004 - val_acc: 0.6955
#
# Epoch 00046: val_acc did not improve from 0.70688
# Epoch 47/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2252 - acc: 0.8879 - val_loss: 0.5914 - val_acc: 0.7010
#
# Epoch 00047: val_acc did not improve from 0.70688
# Epoch 48/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2252 - acc: 0.8881 - val_loss: 0.5899 - val_acc: 0.7035
#
# Epoch 00048: val_acc did not improve from 0.70688
# Epoch 49/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2247 - acc: 0.8887 - val_loss: 0.5910 - val_acc: 0.7010
#
# Epoch 00049: val_acc did not improve from 0.70688
# Epoch 50/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2247 - acc: 0.8882 - val_loss: 0.5951 - val_acc: 0.6988
#
# Epoch 00050: val_acc did not improve from 0.70688
# Epoch 51/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2246 - acc: 0.8885 - val_loss: 0.5887 - val_acc: 0.7033
#
# Epoch 00051: val_acc did not improve from 0.70688
# Epoch 52/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2246 - acc: 0.8878 - val_loss: 0.5897 - val_acc: 0.7024
#
# Epoch 00052: val_acc did not improve from 0.70688
# Epoch 53/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2238 - acc: 0.8887 - val_loss: 0.5928 - val_acc: 0.7024
#
# Epoch 00053: val_acc did not improve from 0.70688
# Epoch 54/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2237 - acc: 0.8888 - val_loss: 0.5906 - val_acc: 0.7010
#
# Epoch 00054: val_acc did not improve from 0.70688
# Epoch 55/120
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.2249 - acc: 0.8879 - val_loss: 0.5915 - val_acc: 0.7010
#
# Epoch 00055: val_acc did not improve from 0.70688
# Epoch 56/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2240 - acc: 0.8884 - val_loss: 0.5941 - val_acc: 0.6996
#
# Epoch 00056: val_acc did not improve from 0.70688
# Epoch 57/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2236 - acc: 0.8892 - val_loss: 0.5938 - val_acc: 0.7002
#
# Epoch 00057: val_acc did not improve from 0.70688
# Epoch 58/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2231 - acc: 0.8895 - val_loss: 0.5899 - val_acc: 0.7024
#
# Epoch 00058: val_acc did not improve from 0.70688
# Epoch 59/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2233 - acc: 0.8892 - val_loss: 0.5914 - val_acc: 0.7021
#
# Epoch 00059: val_acc did not improve from 0.70688
# Epoch 60/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2231 - acc: 0.8891 - val_loss: 0.5963 - val_acc: 0.6980
#
# Epoch 00060: val_acc did not improve from 0.70688
# Epoch 61/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2232 - acc: 0.8890 - val_loss: 0.5916 - val_acc: 0.7013
#
# Epoch 00061: val_acc did not improve from 0.70688
# Epoch 62/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2226 - acc: 0.8894 - val_loss: 0.5929 - val_acc: 0.7016
#
# Epoch 00062: val_acc did not improve from 0.70688
# Epoch 63/120
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.2224 - acc: 0.8893 - val_loss: 0.5944 - val_acc: 0.6994
#
# Epoch 00063: val_acc did not improve from 0.70688
# Epoch 64/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2222 - acc: 0.8895 - val_loss: 0.5949 - val_acc: 0.6980
#
# Epoch 00064: val_acc did not improve from 0.70688
# Epoch 65/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2222 - acc: 0.8899 - val_loss: 0.5934 - val_acc: 0.6999
#
# Epoch 00065: val_acc did not improve from 0.70688
# Epoch 66/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2223 - acc: 0.8898 - val_loss: 0.5972 - val_acc: 0.6969
#
# Epoch 00066: val_acc did not improve from 0.70688
# Epoch 67/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2223 - acc: 0.8889 - val_loss: 0.5992 - val_acc: 0.6969
#
# Epoch 00067: val_acc did not improve from 0.70688
# Epoch 68/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2217 - acc: 0.8897 - val_loss: 0.5957 - val_acc: 0.6988
#
# Epoch 00068: val_acc did not improve from 0.70688
# Epoch 69/120
# 32181/32181 [==============================] - 1s 40us/step - loss: 0.2221 - acc: 0.8891 - val_loss: 0.5966 - val_acc: 0.6982
#
# Epoch 00069: val_acc did not improve from 0.70688
# Epoch 70/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2221 - acc: 0.8896 - val_loss: 0.5977 - val_acc: 0.6971
#
# Epoch 00070: val_acc did not improve from 0.70688
# Epoch 71/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2211 - acc: 0.8902 - val_loss: 0.5910 - val_acc: 0.7008
#
# Epoch 00071: val_acc did not improve from 0.70688
# Epoch 72/120
# 32181/32181 [==============================] - 1s 40us/step - loss: 0.2210 - acc: 0.8906 - val_loss: 0.5928 - val_acc: 0.7024
#
# Epoch 00072: val_acc did not improve from 0.70688
# Epoch 73/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2215 - acc: 0.8897 - val_loss: 0.5887 - val_acc: 0.7030
#
# Epoch 00073: val_acc did not improve from 0.70688
# Epoch 74/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2211 - acc: 0.8904 - val_loss: 0.5950 - val_acc: 0.6996
#
# Epoch 00074: val_acc did not improve from 0.70688
# Epoch 75/120
# 32181/32181 [==============================] - 1s 40us/step - loss: 0.2205 - acc: 0.8902 - val_loss: 0.5891 - val_acc: 0.7033
#
# Epoch 00075: val_acc did not improve from 0.70688
# Epoch 76/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2206 - acc: 0.8906 - val_loss: 0.5945 - val_acc: 0.7008
#
# Epoch 00076: val_acc did not improve from 0.70688
# Epoch 77/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2207 - acc: 0.8904 - val_loss: 0.5973 - val_acc: 0.6985
#
# Epoch 00077: val_acc did not improve from 0.70688
# Epoch 78/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2205 - acc: 0.8905 - val_loss: 0.5968 - val_acc: 0.6980
#
# Epoch 00078: val_acc did not improve from 0.70688
# Epoch 79/120
# 32181/32181 [==============================] - 1s 40us/step - loss: 0.2206 - acc: 0.8906 - val_loss: 0.5971 - val_acc: 0.6985
#
# Epoch 00079: val_acc did not improve from 0.70688
# Epoch 80/120
# 32181/32181 [==============================] - 1s 40us/step - loss: 0.2198 - acc: 0.8907 - val_loss: 0.5963 - val_acc: 0.6991
#
# Epoch 00080: val_acc did not improve from 0.70688
# Epoch 81/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2202 - acc: 0.8905 - val_loss: 0.5953 - val_acc: 0.6999
#
# Epoch 00081: val_acc did not improve from 0.70688
# Epoch 82/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2199 - acc: 0.8903 - val_loss: 0.5965 - val_acc: 0.6988
#
# Epoch 00082: val_acc did not improve from 0.70688
# Epoch 83/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2196 - acc: 0.8910 - val_loss: 0.5982 - val_acc: 0.6977
#
# Epoch 00083: val_acc did not improve from 0.70688
# Epoch 84/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2194 - acc: 0.8909 - val_loss: 0.5990 - val_acc: 0.6974
#
# Epoch 00084: val_acc did not improve from 0.70688
# Epoch 85/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2192 - acc: 0.8910 - val_loss: 0.5986 - val_acc: 0.6974
#
# Epoch 00085: val_acc did not improve from 0.70688
# Epoch 86/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2190 - acc: 0.8915 - val_loss: 0.5937 - val_acc: 0.7027
#
# Epoch 00086: val_acc did not improve from 0.70688
# Epoch 87/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2187 - acc: 0.8915 - val_loss: 0.5959 - val_acc: 0.6991
#
# Epoch 00087: val_acc did not improve from 0.70688
# Epoch 88/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2184 - acc: 0.8918 - val_loss: 0.5976 - val_acc: 0.6985
#
# Epoch 00088: val_acc did not improve from 0.70688
# Epoch 89/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2181 - acc: 0.8921 - val_loss: 0.5965 - val_acc: 0.7002
#
# Epoch 00089: val_acc did not improve from 0.70688
# Epoch 90/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2183 - acc: 0.8918 - val_loss: 0.5972 - val_acc: 0.6982
#
# Epoch 00090: val_acc did not improve from 0.70688
# Epoch 91/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2182 - acc: 0.8918 - val_loss: 0.5972 - val_acc: 0.6991
#
# Epoch 00091: val_acc did not improve from 0.70688
# Epoch 92/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2173 - acc: 0.8921 - val_loss: 0.5983 - val_acc: 0.6985
#
# Epoch 00092: val_acc did not improve from 0.70688
# Epoch 93/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2182 - acc: 0.8917 - val_loss: 0.5994 - val_acc: 0.6969
#
# Epoch 00093: val_acc did not improve from 0.70688
# Epoch 94/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2189 - acc: 0.8908 - val_loss: 0.5935 - val_acc: 0.7019
#
# Epoch 00094: val_acc did not improve from 0.70688
# Epoch 95/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2178 - acc: 0.8912 - val_loss: 0.5999 - val_acc: 0.6963
#
# Epoch 00095: val_acc did not improve from 0.70688
# Epoch 96/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2166 - acc: 0.8927 - val_loss: 0.5998 - val_acc: 0.6971
#
# Epoch 00096: val_acc did not improve from 0.70688
# Epoch 97/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2167 - acc: 0.8929 - val_loss: 0.5989 - val_acc: 0.6977
#
# Epoch 00097: val_acc did not improve from 0.70688
# Epoch 98/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2175 - acc: 0.8919 - val_loss: 0.5989 - val_acc: 0.6977
#
# Epoch 00098: val_acc did not improve from 0.70688
# Epoch 99/120
# 32181/32181 [==============================] - 1s 40us/step - loss: 0.2167 - acc: 0.8923 - val_loss: 0.6010 - val_acc: 0.6955
#
# Epoch 00099: val_acc did not improve from 0.70688
# Epoch 100/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2171 - acc: 0.8925 - val_loss: 0.5973 - val_acc: 0.6977
#
# Epoch 00100: val_acc did not improve from 0.70688
# Epoch 101/120
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.2168 - acc: 0.8928 - val_loss: 0.5965 - val_acc: 0.7008
#
# Epoch 00101: val_acc did not improve from 0.70688
# Epoch 102/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2166 - acc: 0.8923 - val_loss: 0.5970 - val_acc: 0.6996
#
# Epoch 00102: val_acc did not improve from 0.70688
# Epoch 103/120
# 32181/32181 [==============================] - 1s 40us/step - loss: 0.2167 - acc: 0.8925 - val_loss: 0.6029 - val_acc: 0.6952
#
# Epoch 00103: val_acc did not improve from 0.70688
# Epoch 104/120
# 32181/32181 [==============================] - 1s 40us/step - loss: 0.2162 - acc: 0.8928 - val_loss: 0.6006 - val_acc: 0.6969
#
# Epoch 00104: val_acc did not improve from 0.70688
# Epoch 105/120
# 32181/32181 [==============================] - 1s 40us/step - loss: 0.2159 - acc: 0.8930 - val_loss: 0.6037 - val_acc: 0.6969
#
# Epoch 00105: val_acc did not improve from 0.70688
# Epoch 106/120
# 32181/32181 [==============================] - 1s 40us/step - loss: 0.2165 - acc: 0.8928 - val_loss: 0.5958 - val_acc: 0.6999
#
# Epoch 00106: val_acc did not improve from 0.70688
# Epoch 107/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2165 - acc: 0.8925 - val_loss: 0.6013 - val_acc: 0.6971
#
# Epoch 00107: val_acc did not improve from 0.70688
# Epoch 108/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2155 - acc: 0.8932 - val_loss: 0.6080 - val_acc: 0.6932
#
# Epoch 00108: val_acc did not improve from 0.70688
# Epoch 109/120
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.2158 - acc: 0.8928 - val_loss: 0.6004 - val_acc: 0.6966
#
# Epoch 00109: val_acc did not improve from 0.70688
# Epoch 110/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2146 - acc: 0.8935 - val_loss: 0.5996 - val_acc: 0.6977
#
# Epoch 00110: val_acc did not improve from 0.70688
# Epoch 111/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2154 - acc: 0.8930 - val_loss: 0.6002 - val_acc: 0.6982
#
# Epoch 00111: val_acc did not improve from 0.70688
# Epoch 112/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2150 - acc: 0.8935 - val_loss: 0.5998 - val_acc: 0.6974
#
# Epoch 00112: val_acc did not improve from 0.70688
# Epoch 113/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2151 - acc: 0.8933 - val_loss: 0.5971 - val_acc: 0.6994
#
# Epoch 00113: val_acc did not improve from 0.70688
# Epoch 114/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2145 - acc: 0.8937 - val_loss: 0.6015 - val_acc: 0.6957
#
# Epoch 00114: val_acc did not improve from 0.70688
# Epoch 115/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2148 - acc: 0.8934 - val_loss: 0.5982 - val_acc: 0.6969
#
# Epoch 00115: val_acc did not improve from 0.70688
# Epoch 116/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2146 - acc: 0.8935 - val_loss: 0.5983 - val_acc: 0.7002
#
# Epoch 00116: val_acc did not improve from 0.70688
# Epoch 117/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2145 - acc: 0.8937 - val_loss: 0.5999 - val_acc: 0.6969
#
# Epoch 00117: val_acc did not improve from 0.70688
# Epoch 118/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2137 - acc: 0.8939 - val_loss: 0.5986 - val_acc: 0.6982
#
# Epoch 00118: val_acc did not improve from 0.70688
# Epoch 119/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2137 - acc: 0.8940 - val_loss: 0.6028 - val_acc: 0.6963
#
# Epoch 00119: val_acc did not improve from 0.70688
# Epoch 120/120
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.2141 - acc: 0.8936 - val_loss: 0.5973 - val_acc: 0.6985
#
# Epoch 00120: val_acc did not improve from 0.70688

# %% [markdown]
# #### Load the best  ensembling NN model

# %%
filepath = file_prefix + r"ensemble_hinge.best.hdf5"
ensemble_model = load_model(filepath)

# %%
y_pred_ensemble = ensemble_model.predict(x_test_ensemble)

# %%
Y_NN_Ense_pred = []
for row in y_pred_ensemble:
    a = numpy.argmax(np.array(row)) #return the indices of the maximum values along the axis
    Y_NN_Ense_pred.append(a)

# %%
Y_NN_Ense_pred_np = np.array(Y_NN_Ense_pred)
private_set_y_np  = np.array(private_set_y)

# %%
count_correct = np.sum(Y_NN_Ense_pred_np == private_set_y_np)

# %%
len(Y_NN_Ense_pred_np), count_correct
# Out:
# (3589, 2537)

# %%
Y_Hinge_Ense_accuracy = (float(count_correct)/len(Y_NN_Ense_pred_np))

# %%
print("Accuracy of Hinge Loss Ensembling on Private Leader Board Data:"+str(Y_Hinge_Ense_accuracy))
# Out:
# Accuracy of Hinge Loss Ensembling on Private Leader Board Data:0.7068821398718306

# %% [markdown]
# ### Obeservation
# Using Hinge Loss Ensembling, we could slightly improve the performace of the prediction model from **0.6937** to **0.7068**

# %% [markdown]
# #### Record the performance metrics

# %%
 ModelPerformance.loc[len(ModelPerformance)] = ['Hinge Ensembling +  CNN', Y_Hinge_Ense_accuracy]

# %% [markdown]
# ## 9.3 Optimal Mean Squred Error (MSE) Ensembling

# %% [markdown]
# #### Since the training and testing data is already prepared in  9.2 we just need to train the model here

# %% [markdown]
# ####  Define all the callback functions for the ensembling NN  model here

# %%
#Callback for saving the best ensembling NN model

filepath = file_prefix + r"ensemble_mse.best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# %% [markdown]
# #### Define the ensembling NN model

# %%
def ensemble_model_generate():
    nb_classes, nb_peturbations = 7, 8

    model = Sequential()
    model.add(Flatten(input_shape=(nb_classes* nb_peturbations, 1)))
    model.add(Activation('relu'))
    model.add(Dense(1024))
    model.add(Activation('relu'))
    model.add(Dense(1024))
    model.add(Activation('relu'))
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dense(7))
    model.add(Activation('softmax'))

    #adam = keras.optimizers.Adam(lr=0.01, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
    sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
    #categorical_hinge, squared_hinge, mean_squared_error,sparse_categorical_crossentropy
    model.compile(loss='mean_squared_error',
    optimizer=sgd,
    metrics=['accuracy'])
    model.summary()
    return model

# %%
try:
    del ensemble_model # does model exist in the current namespace
except NameError:
    pass


ensemble_model = ensemble_model_generate()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_11 (Flatten)         (None, 56)                0
# _________________________________________________________________
# activation_56 (Activation)   (None, 56)                0
# _________________________________________________________________
# dense_41 (Dense)             (None, 1024)              58368
# _________________________________________________________________
# activation_57 (Activation)   (None, 1024)              0
# _________________________________________________________________
# dense_42 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# activation_58 (Activation)   (None, 1024)              0
# _________________________________________________________________
# dense_43 (Dense)             (None, 512)               524800
# _________________________________________________________________
# activation_59 (Activation)   (None, 512)               0
# _________________________________________________________________
# dense_44 (Dense)             (None, 7)                 3591
# _________________________________________________________________
# activation_60 (Activation)   (None, 7)                 0
# =================================================================
# Total params: 1,636,359
# Trainable params: 1,636,359
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Train the MSE ensembling model

# %%
callbacks_list = [checkpoint]

# %%
ensemble_model.fit(x_train_ensemble, Y_train_t,
          batch_size=128,
          epochs=300,
          verbose=1,
          class_weight=class_weights,
          validation_data=(x_val_ensemble, Y_val_t),
          callbacks=callbacks_list)
# Out:
# Train on 32181 samples, validate on 3589 samples
# Epoch 1/300
# 32181/32181 [==============================] - 2s 59us/step - loss: 0.1002 - acc: 0.6661 - val_loss: 0.0830 - val_acc: 0.6801
#
# Epoch 00001: val_acc improved from -inf to 0.68013, saving model to Final_Subm_FER_Tony_v1_ensemble_mse.best.hdf5
# Epoch 2/300
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.0499 - acc: 0.8485 - val_loss: 0.0619 - val_acc: 0.6938
#
# Epoch 00002: val_acc improved from 0.68013 to 0.69379, saving model to Final_Subm_FER_Tony_v1_ensemble_mse.best.hdf5
# Epoch 3/300
# 32181/32181 [==============================] - 1s 43us/step - loss: 0.0309 - acc: 0.8597 - val_loss: 0.0624 - val_acc: 0.6913
#
# Epoch 00003: val_acc did not improve from 0.69379
# Epoch 4/300
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.0287 - acc: 0.8618 - val_loss: 0.0633 - val_acc: 0.6930
#
# Epoch 00004: val_acc did not improve from 0.69379
# Epoch 5/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0281 - acc: 0.8626 - val_loss: 0.0637 - val_acc: 0.6938
#
# Epoch 00005: val_acc did not improve from 0.69379
# Epoch 6/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0277 - acc: 0.8686 - val_loss: 0.0638 - val_acc: 0.7008
#
# Epoch 00006: val_acc improved from 0.69379 to 0.70075, saving model to Final_Subm_FER_Tony_v1_ensemble_mse.best.hdf5
# Epoch 7/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0273 - acc: 0.8747 - val_loss: 0.0638 - val_acc: 0.7033
#
# Epoch 00007: val_acc improved from 0.70075 to 0.70326, saving model to Final_Subm_FER_Tony_v1_ensemble_mse.best.hdf5
# Epoch 8/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0268 - acc: 0.8769 - val_loss: 0.0637 - val_acc: 0.7047
#
# Epoch 00008: val_acc improved from 0.70326 to 0.70465, saving model to Final_Subm_FER_Tony_v1_ensemble_mse.best.hdf5
# Epoch 9/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0264 - acc: 0.8781 - val_loss: 0.0635 - val_acc: 0.7038
#
# Epoch 00009: val_acc did not improve from 0.70465
# Epoch 10/300
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.0261 - acc: 0.8782 - val_loss: 0.0635 - val_acc: 0.7044
#
# Epoch 00010: val_acc did not improve from 0.70465
# Epoch 11/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0258 - acc: 0.8787 - val_loss: 0.0635 - val_acc: 0.7041
#
# Epoch 00011: val_acc did not improve from 0.70465
# Epoch 12/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0257 - acc: 0.8796 - val_loss: 0.0635 - val_acc: 0.7041
#
# Epoch 00012: val_acc did not improve from 0.70465
# Epoch 13/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0255 - acc: 0.8796 - val_loss: 0.0635 - val_acc: 0.7047
#
# Epoch 00013: val_acc did not improve from 0.70465
# Epoch 14/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0254 - acc: 0.8799 - val_loss: 0.0635 - val_acc: 0.7058
#
# Epoch 00014: val_acc improved from 0.70465 to 0.70577, saving model to Final_Subm_FER_Tony_v1_ensemble_mse.best.hdf5
# Epoch 15/300
# 32181/32181 [==============================] - 1s 43us/step - loss: 0.0253 - acc: 0.8794 - val_loss: 0.0635 - val_acc: 0.7060
#
# Epoch 00015: val_acc improved from 0.70577 to 0.70605, saving model to Final_Subm_FER_Tony_v1_ensemble_mse.best.hdf5
# Epoch 16/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0253 - acc: 0.8803 - val_loss: 0.0634 - val_acc: 0.7038
#
# Epoch 00016: val_acc did not improve from 0.70605
# Epoch 17/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0252 - acc: 0.8806 - val_loss: 0.0634 - val_acc: 0.7052
#
# Epoch 00017: val_acc did not improve from 0.70605
# Epoch 18/300
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.0252 - acc: 0.8808 - val_loss: 0.0635 - val_acc: 0.7058
#
# Epoch 00018: val_acc did not improve from 0.70605
# Epoch 19/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0251 - acc: 0.8804 - val_loss: 0.0634 - val_acc: 0.7055
#
# Epoch 00019: val_acc did not improve from 0.70605
# Epoch 20/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0250 - acc: 0.8811 - val_loss: 0.0633 - val_acc: 0.7052
#
# Epoch 00020: val_acc did not improve from 0.70605
# Epoch 21/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0250 - acc: 0.8811 - val_loss: 0.0634 - val_acc: 0.7047
#
# Epoch 00021: val_acc did not improve from 0.70605
# Epoch 22/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0250 - acc: 0.8815 - val_loss: 0.0633 - val_acc: 0.7052
#
# Epoch 00022: val_acc did not improve from 0.70605
# Epoch 23/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0249 - acc: 0.8815 - val_loss: 0.0633 - val_acc: 0.7049
#
# Epoch 00023: val_acc did not improve from 0.70605
# Epoch 24/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0249 - acc: 0.8815 - val_loss: 0.0633 - val_acc: 0.7055
#
# Epoch 00024: val_acc did not improve from 0.70605
# Epoch 25/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0248 - acc: 0.8816 - val_loss: 0.0633 - val_acc: 0.7035
#
# Epoch 00025: val_acc did not improve from 0.70605
# Epoch 26/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0248 - acc: 0.8818 - val_loss: 0.0634 - val_acc: 0.7060
#
# Epoch 00026: val_acc did not improve from 0.70605
# Epoch 27/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0248 - acc: 0.8824 - val_loss: 0.0633 - val_acc: 0.7052
#
# Epoch 00027: val_acc did not improve from 0.70605
# Epoch 28/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0247 - acc: 0.8824 - val_loss: 0.0633 - val_acc: 0.7063
#
# Epoch 00028: val_acc improved from 0.70605 to 0.70632, saving model to Final_Subm_FER_Tony_v1_ensemble_mse.best.hdf5
# Epoch 29/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0247 - acc: 0.8822 - val_loss: 0.0633 - val_acc: 0.7044
#
# Epoch 00029: val_acc did not improve from 0.70632
# Epoch 30/300
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.0247 - acc: 0.8821 - val_loss: 0.0633 - val_acc: 0.7060
#
# Epoch 00030: val_acc did not improve from 0.70632
# Epoch 31/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0247 - acc: 0.8826 - val_loss: 0.0633 - val_acc: 0.7055
#
# Epoch 00031: val_acc did not improve from 0.70632
# Epoch 32/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0246 - acc: 0.8822 - val_loss: 0.0633 - val_acc: 0.7060
#
# Epoch 00032: val_acc did not improve from 0.70632
# Epoch 33/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0246 - acc: 0.8822 - val_loss: 0.0634 - val_acc: 0.7049
#
# Epoch 00033: val_acc did not improve from 0.70632
# Epoch 34/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0246 - acc: 0.8824 - val_loss: 0.0633 - val_acc: 0.7047
#
# Epoch 00034: val_acc did not improve from 0.70632
# Epoch 35/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0246 - acc: 0.8821 - val_loss: 0.0634 - val_acc: 0.7049
#
# Epoch 00035: val_acc did not improve from 0.70632
# Epoch 36/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0245 - acc: 0.8824 - val_loss: 0.0633 - val_acc: 0.7055
#
# Epoch 00036: val_acc did not improve from 0.70632
# Epoch 37/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0245 - acc: 0.8831 - val_loss: 0.0634 - val_acc: 0.7058
#
# Epoch 00037: val_acc did not improve from 0.70632
# Epoch 38/300
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.0245 - acc: 0.8831 - val_loss: 0.0634 - val_acc: 0.7058
#
# Epoch 00038: val_acc did not improve from 0.70632
# Epoch 39/300
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.0245 - acc: 0.8829 - val_loss: 0.0634 - val_acc: 0.7041
#
# Epoch 00039: val_acc did not improve from 0.70632
# Epoch 40/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0245 - acc: 0.8833 - val_loss: 0.0634 - val_acc: 0.7052
#
# Epoch 00040: val_acc did not improve from 0.70632
# Epoch 41/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0244 - acc: 0.8832 - val_loss: 0.0634 - val_acc: 0.7052
#
# Epoch 00041: val_acc did not improve from 0.70632
# Epoch 42/300
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.0244 - acc: 0.8832 - val_loss: 0.0634 - val_acc: 0.7055
#
# Epoch 00042: val_acc did not improve from 0.70632
# Epoch 43/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0244 - acc: 0.8834 - val_loss: 0.0634 - val_acc: 0.7055
#
# Epoch 00043: val_acc did not improve from 0.70632
# Epoch 44/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0244 - acc: 0.8831 - val_loss: 0.0634 - val_acc: 0.7055
#
# Epoch 00044: val_acc did not improve from 0.70632
# Epoch 45/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0244 - acc: 0.8835 - val_loss: 0.0634 - val_acc: 0.7052
#
# Epoch 00045: val_acc did not improve from 0.70632
# Epoch 46/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0244 - acc: 0.8836 - val_loss: 0.0635 - val_acc: 0.7060
#
# Epoch 00046: val_acc did not improve from 0.70632
# Epoch 47/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0244 - acc: 0.8836 - val_loss: 0.0635 - val_acc: 0.7047
#
# Epoch 00047: val_acc did not improve from 0.70632
# Epoch 48/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0243 - acc: 0.8833 - val_loss: 0.0634 - val_acc: 0.7047
#
# Epoch 00048: val_acc did not improve from 0.70632
# Epoch 49/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0243 - acc: 0.8836 - val_loss: 0.0634 - val_acc: 0.7058
#
# Epoch 00049: val_acc did not improve from 0.70632
# Epoch 50/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0243 - acc: 0.8836 - val_loss: 0.0635 - val_acc: 0.7055
#
# Epoch 00050: val_acc did not improve from 0.70632
# Epoch 51/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0243 - acc: 0.8838 - val_loss: 0.0635 - val_acc: 0.7055
#
# Epoch 00051: val_acc did not improve from 0.70632
# Epoch 52/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0243 - acc: 0.8837 - val_loss: 0.0635 - val_acc: 0.7060
#
# Epoch 00052: val_acc did not improve from 0.70632
# Epoch 53/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0243 - acc: 0.8838 - val_loss: 0.0635 - val_acc: 0.7058
#
# Epoch 00053: val_acc did not improve from 0.70632
# Epoch 54/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0242 - acc: 0.8836 - val_loss: 0.0635 - val_acc: 0.7041
#
# Epoch 00054: val_acc did not improve from 0.70632
# Epoch 55/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0242 - acc: 0.8836 - val_loss: 0.0635 - val_acc: 0.7058
#
# Epoch 00055: val_acc did not improve from 0.70632
# Epoch 56/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0242 - acc: 0.8838 - val_loss: 0.0635 - val_acc: 0.7055
#
# Epoch 00056: val_acc did not improve from 0.70632
# Epoch 57/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0242 - acc: 0.8842 - val_loss: 0.0636 - val_acc: 0.7047
#
# Epoch 00057: val_acc did not improve from 0.70632
# Epoch 58/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0242 - acc: 0.8835 - val_loss: 0.0635 - val_acc: 0.7047
#
# Epoch 00058: val_acc did not improve from 0.70632
# Epoch 59/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0242 - acc: 0.8837 - val_loss: 0.0635 - val_acc: 0.7060
#
# Epoch 00059: val_acc did not improve from 0.70632
# Epoch 60/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0242 - acc: 0.8839 - val_loss: 0.0635 - val_acc: 0.7047
#
# Epoch 00060: val_acc did not improve from 0.70632
# Epoch 61/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0242 - acc: 0.8841 - val_loss: 0.0636 - val_acc: 0.7058
#
# Epoch 00061: val_acc did not improve from 0.70632
# Epoch 62/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0242 - acc: 0.8838 - val_loss: 0.0636 - val_acc: 0.7058
#
# Epoch 00062: val_acc did not improve from 0.70632
# Epoch 63/300
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.0241 - acc: 0.8837 - val_loss: 0.0636 - val_acc: 0.7058
#
# Epoch 00063: val_acc did not improve from 0.70632
# Epoch 64/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0241 - acc: 0.8838 - val_loss: 0.0636 - val_acc: 0.7060
#
# Epoch 00064: val_acc did not improve from 0.70632
# Epoch 65/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0241 - acc: 0.8837 - val_loss: 0.0636 - val_acc: 0.7066
#
# Epoch 00065: val_acc improved from 0.70632 to 0.70660, saving model to Final_Subm_FER_Tony_v1_ensemble_mse.best.hdf5
# Epoch 66/300
# 32181/32181 [==============================] - 1s 43us/step - loss: 0.0241 - acc: 0.8838 - val_loss: 0.0636 - val_acc: 0.7060
#
# Epoch 00066: val_acc did not improve from 0.70660
# Epoch 67/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0241 - acc: 0.8839 - val_loss: 0.0636 - val_acc: 0.7049
#
# Epoch 00067: val_acc did not improve from 0.70660
# Epoch 68/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0241 - acc: 0.8840 - val_loss: 0.0636 - val_acc: 0.7055
#
# Epoch 00068: val_acc did not improve from 0.70660
# Epoch 69/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0241 - acc: 0.8844 - val_loss: 0.0636 - val_acc: 0.7041
#
# Epoch 00069: val_acc did not improve from 0.70660
# Epoch 70/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0241 - acc: 0.8843 - val_loss: 0.0636 - val_acc: 0.7063
#
# Epoch 00070: val_acc did not improve from 0.70660
# Epoch 71/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0241 - acc: 0.8840 - val_loss: 0.0636 - val_acc: 0.7052
#
# Epoch 00071: val_acc did not improve from 0.70660
# Epoch 72/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0241 - acc: 0.8842 - val_loss: 0.0637 - val_acc: 0.7055
#
# Epoch 00072: val_acc did not improve from 0.70660
# Epoch 73/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0241 - acc: 0.8844 - val_loss: 0.0637 - val_acc: 0.7060
#
# Epoch 00073: val_acc did not improve from 0.70660
# Epoch 74/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0241 - acc: 0.8837 - val_loss: 0.0637 - val_acc: 0.7066
#
# Epoch 00074: val_acc did not improve from 0.70660
# Epoch 75/300
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.0240 - acc: 0.8843 - val_loss: 0.0637 - val_acc: 0.7033
#
# Epoch 00075: val_acc did not improve from 0.70660
# Epoch 76/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0240 - acc: 0.8845 - val_loss: 0.0637 - val_acc: 0.7055
#
# Epoch 00076: val_acc did not improve from 0.70660
# Epoch 77/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0240 - acc: 0.8845 - val_loss: 0.0636 - val_acc: 0.7058
#
# Epoch 00077: val_acc did not improve from 0.70660
# Epoch 78/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0240 - acc: 0.8842 - val_loss: 0.0636 - val_acc: 0.7055
#
# Epoch 00078: val_acc did not improve from 0.70660
# Epoch 79/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0240 - acc: 0.8845 - val_loss: 0.0637 - val_acc: 0.7055
#
# Epoch 00079: val_acc did not improve from 0.70660
# Epoch 80/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0240 - acc: 0.8844 - val_loss: 0.0637 - val_acc: 0.7041
#
# Epoch 00080: val_acc did not improve from 0.70660
# Epoch 81/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0240 - acc: 0.8850 - val_loss: 0.0638 - val_acc: 0.7055
#
# Epoch 00081: val_acc did not improve from 0.70660
# Epoch 82/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0240 - acc: 0.8847 - val_loss: 0.0637 - val_acc: 0.7047
#
# Epoch 00082: val_acc did not improve from 0.70660
# Epoch 83/300
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.0240 - acc: 0.8844 - val_loss: 0.0637 - val_acc: 0.7063
#
# Epoch 00083: val_acc did not improve from 0.70660
# Epoch 84/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0240 - acc: 0.8843 - val_loss: 0.0637 - val_acc: 0.7066
#
# Epoch 00084: val_acc did not improve from 0.70660
# Epoch 85/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0240 - acc: 0.8847 - val_loss: 0.0637 - val_acc: 0.7049
#
# Epoch 00085: val_acc did not improve from 0.70660
# Epoch 86/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0240 - acc: 0.8842 - val_loss: 0.0637 - val_acc: 0.7052
#
# Epoch 00086: val_acc did not improve from 0.70660
# Epoch 87/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0239 - acc: 0.8846 - val_loss: 0.0637 - val_acc: 0.7060
#
# Epoch 00087: val_acc did not improve from 0.70660
# Epoch 88/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0239 - acc: 0.8846 - val_loss: 0.0638 - val_acc: 0.7060
#
# Epoch 00088: val_acc did not improve from 0.70660
# Epoch 89/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0239 - acc: 0.8843 - val_loss: 0.0638 - val_acc: 0.7047
#
# Epoch 00089: val_acc did not improve from 0.70660
# Epoch 90/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0239 - acc: 0.8844 - val_loss: 0.0637 - val_acc: 0.7055
#
# Epoch 00090: val_acc did not improve from 0.70660
# Epoch 91/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0239 - acc: 0.8849 - val_loss: 0.0638 - val_acc: 0.7055
#
# Epoch 00091: val_acc did not improve from 0.70660
# Epoch 92/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0239 - acc: 0.8847 - val_loss: 0.0638 - val_acc: 0.7049
#
# Epoch 00092: val_acc did not improve from 0.70660
# Epoch 93/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0239 - acc: 0.8846 - val_loss: 0.0637 - val_acc: 0.7047
#
# Epoch 00093: val_acc did not improve from 0.70660
# Epoch 94/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0239 - acc: 0.8842 - val_loss: 0.0638 - val_acc: 0.7060
#
# Epoch 00094: val_acc did not improve from 0.70660
# Epoch 95/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0239 - acc: 0.8853 - val_loss: 0.0637 - val_acc: 0.7041
#
# Epoch 00095: val_acc did not improve from 0.70660
# Epoch 96/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0239 - acc: 0.8844 - val_loss: 0.0638 - val_acc: 0.7049
#
# Epoch 00096: val_acc did not improve from 0.70660
# Epoch 97/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0239 - acc: 0.8849 - val_loss: 0.0638 - val_acc: 0.7035
#
# Epoch 00097: val_acc did not improve from 0.70660
# Epoch 98/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0239 - acc: 0.8850 - val_loss: 0.0638 - val_acc: 0.7052
#
# Epoch 00098: val_acc did not improve from 0.70660
# Epoch 99/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0238 - acc: 0.8848 - val_loss: 0.0638 - val_acc: 0.7047
#
# Epoch 00099: val_acc did not improve from 0.70660
# Epoch 100/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0239 - acc: 0.8849 - val_loss: 0.0638 - val_acc: 0.7044
#
# Epoch 00100: val_acc did not improve from 0.70660
# Epoch 101/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0238 - acc: 0.8845 - val_loss: 0.0638 - val_acc: 0.7066
#
# Epoch 00101: val_acc did not improve from 0.70660
# Epoch 102/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0238 - acc: 0.8848 - val_loss: 0.0638 - val_acc: 0.7063
#
# Epoch 00102: val_acc did not improve from 0.70660
# Epoch 103/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0238 - acc: 0.8850 - val_loss: 0.0639 - val_acc: 0.7060
#
# Epoch 00103: val_acc did not improve from 0.70660
# Epoch 104/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0238 - acc: 0.8851 - val_loss: 0.0638 - val_acc: 0.7047
#
# Epoch 00104: val_acc did not improve from 0.70660
# Epoch 105/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0238 - acc: 0.8854 - val_loss: 0.0638 - val_acc: 0.7049
#
# Epoch 00105: val_acc did not improve from 0.70660
# Epoch 106/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0238 - acc: 0.8848 - val_loss: 0.0638 - val_acc: 0.7066
#
# Epoch 00106: val_acc did not improve from 0.70660
# Epoch 107/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0238 - acc: 0.8854 - val_loss: 0.0639 - val_acc: 0.7066
#
# Epoch 00107: val_acc did not improve from 0.70660
# Epoch 108/300
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.0238 - acc: 0.8849 - val_loss: 0.0639 - val_acc: 0.7058
#
# Epoch 00108: val_acc did not improve from 0.70660
# Epoch 109/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0238 - acc: 0.8849 - val_loss: 0.0638 - val_acc: 0.7041
#
# Epoch 00109: val_acc did not improve from 0.70660
# Epoch 110/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0238 - acc: 0.8847 - val_loss: 0.0639 - val_acc: 0.7052
#
# Epoch 00110: val_acc did not improve from 0.70660
# Epoch 111/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0238 - acc: 0.8850 - val_loss: 0.0639 - val_acc: 0.7027
#
# Epoch 00111: val_acc did not improve from 0.70660
# Epoch 112/300
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.0238 - acc: 0.8853 - val_loss: 0.0639 - val_acc: 0.7058
#
# Epoch 00112: val_acc did not improve from 0.70660
# Epoch 113/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0238 - acc: 0.8846 - val_loss: 0.0638 - val_acc: 0.7044
#
# Epoch 00113: val_acc did not improve from 0.70660
# Epoch 114/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0238 - acc: 0.8854 - val_loss: 0.0639 - val_acc: 0.7055
#
# Epoch 00114: val_acc did not improve from 0.70660
# Epoch 115/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0238 - acc: 0.8853 - val_loss: 0.0640 - val_acc: 0.7052
#
# Epoch 00115: val_acc did not improve from 0.70660
# Epoch 116/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0238 - acc: 0.8850 - val_loss: 0.0639 - val_acc: 0.7044
#
# Epoch 00116: val_acc did not improve from 0.70660
# Epoch 117/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0237 - acc: 0.8852 - val_loss: 0.0639 - val_acc: 0.7035
#
# Epoch 00117: val_acc did not improve from 0.70660
# Epoch 118/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0237 - acc: 0.8856 - val_loss: 0.0639 - val_acc: 0.7060
#
# Epoch 00118: val_acc did not improve from 0.70660
# Epoch 119/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0237 - acc: 0.8855 - val_loss: 0.0639 - val_acc: 0.7035
#
# Epoch 00119: val_acc did not improve from 0.70660
# Epoch 120/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0237 - acc: 0.8851 - val_loss: 0.0639 - val_acc: 0.7058
#
# Epoch 00120: val_acc did not improve from 0.70660
# Epoch 121/300
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.0237 - acc: 0.8854 - val_loss: 0.0639 - val_acc: 0.7041
#
# Epoch 00121: val_acc did not improve from 0.70660
# Epoch 122/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0237 - acc: 0.8860 - val_loss: 0.0640 - val_acc: 0.7052
#
# Epoch 00122: val_acc did not improve from 0.70660
# Epoch 123/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0237 - acc: 0.8855 - val_loss: 0.0639 - val_acc: 0.7052
#
# Epoch 00123: val_acc did not improve from 0.70660
# Epoch 124/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0237 - acc: 0.8853 - val_loss: 0.0639 - val_acc: 0.7052
#
# Epoch 00124: val_acc did not improve from 0.70660
# Epoch 125/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0237 - acc: 0.8856 - val_loss: 0.0639 - val_acc: 0.7049
#
# Epoch 00125: val_acc did not improve from 0.70660
# Epoch 126/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0237 - acc: 0.8857 - val_loss: 0.0639 - val_acc: 0.7047
#
# Epoch 00126: val_acc did not improve from 0.70660
# Epoch 127/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0237 - acc: 0.8852 - val_loss: 0.0639 - val_acc: 0.7052
#
# Epoch 00127: val_acc did not improve from 0.70660
# Epoch 128/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0237 - acc: 0.8849 - val_loss: 0.0639 - val_acc: 0.7055
#
# Epoch 00128: val_acc did not improve from 0.70660
# Epoch 129/300
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.0237 - acc: 0.8854 - val_loss: 0.0640 - val_acc: 0.7035
#
# Epoch 00129: val_acc did not improve from 0.70660
# Epoch 130/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0237 - acc: 0.8855 - val_loss: 0.0639 - val_acc: 0.7044
#
# Epoch 00130: val_acc did not improve from 0.70660
# Epoch 131/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0237 - acc: 0.8855 - val_loss: 0.0639 - val_acc: 0.7049
#
# Epoch 00131: val_acc did not improve from 0.70660
# Epoch 132/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0237 - acc: 0.8857 - val_loss: 0.0639 - val_acc: 0.7047
#
# Epoch 00132: val_acc did not improve from 0.70660
# Epoch 133/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0237 - acc: 0.8860 - val_loss: 0.0640 - val_acc: 0.7060
#
# Epoch 00133: val_acc did not improve from 0.70660
# Epoch 134/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0236 - acc: 0.8865 - val_loss: 0.0640 - val_acc: 0.7049
#
# Epoch 00134: val_acc did not improve from 0.70660
# Epoch 135/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0237 - acc: 0.8854 - val_loss: 0.0640 - val_acc: 0.7052
#
# Epoch 00135: val_acc did not improve from 0.70660
# Epoch 136/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0236 - acc: 0.8855 - val_loss: 0.0640 - val_acc: 0.7069
#
# Epoch 00136: val_acc improved from 0.70660 to 0.70688, saving model to Final_Subm_FER_Tony_v1_ensemble_mse.best.hdf5
# Epoch 137/300
# 32181/32181 [==============================] - 1s 43us/step - loss: 0.0236 - acc: 0.8857 - val_loss: 0.0639 - val_acc: 0.7058
#
# Epoch 00137: val_acc did not improve from 0.70688
# Epoch 138/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0236 - acc: 0.8858 - val_loss: 0.0640 - val_acc: 0.7066
#
# Epoch 00138: val_acc did not improve from 0.70688
# Epoch 139/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0236 - acc: 0.8863 - val_loss: 0.0640 - val_acc: 0.7063
#
# Epoch 00139: val_acc did not improve from 0.70688
# Epoch 140/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0236 - acc: 0.8857 - val_loss: 0.0639 - val_acc: 0.7058
#
# Epoch 00140: val_acc did not improve from 0.70688
# Epoch 141/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0236 - acc: 0.8857 - val_loss: 0.0639 - val_acc: 0.7047
#
# Epoch 00141: val_acc did not improve from 0.70688
# Epoch 142/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0236 - acc: 0.8860 - val_loss: 0.0640 - val_acc: 0.7066
#
# Epoch 00142: val_acc did not improve from 0.70688
# Epoch 143/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0236 - acc: 0.8862 - val_loss: 0.0640 - val_acc: 0.7038
#
# Epoch 00143: val_acc did not improve from 0.70688
# Epoch 144/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0236 - acc: 0.8860 - val_loss: 0.0640 - val_acc: 0.7052
#
# Epoch 00144: val_acc did not improve from 0.70688
# Epoch 145/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0236 - acc: 0.8859 - val_loss: 0.0640 - val_acc: 0.7052
#
# Epoch 00145: val_acc did not improve from 0.70688
# Epoch 146/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0236 - acc: 0.8859 - val_loss: 0.0641 - val_acc: 0.7060
#
# Epoch 00146: val_acc did not improve from 0.70688
# Epoch 147/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0236 - acc: 0.8858 - val_loss: 0.0641 - val_acc: 0.7055
#
# Epoch 00147: val_acc did not improve from 0.70688
# Epoch 148/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0236 - acc: 0.8861 - val_loss: 0.0640 - val_acc: 0.7049
#
# Epoch 00148: val_acc did not improve from 0.70688
# Epoch 149/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0236 - acc: 0.8864 - val_loss: 0.0641 - val_acc: 0.7058
#
# Epoch 00149: val_acc did not improve from 0.70688
# Epoch 150/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0236 - acc: 0.8861 - val_loss: 0.0641 - val_acc: 0.7058
#
# Epoch 00150: val_acc did not improve from 0.70688
# Epoch 151/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0236 - acc: 0.8860 - val_loss: 0.0641 - val_acc: 0.7052
#
# Epoch 00151: val_acc did not improve from 0.70688
# Epoch 152/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0236 - acc: 0.8863 - val_loss: 0.0641 - val_acc: 0.7055
#
# Epoch 00152: val_acc did not improve from 0.70688
# Epoch 153/300
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.0236 - acc: 0.8865 - val_loss: 0.0641 - val_acc: 0.7060
#
# Epoch 00153: val_acc did not improve from 0.70688
# Epoch 154/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0235 - acc: 0.8865 - val_loss: 0.0641 - val_acc: 0.7072
#
# Epoch 00154: val_acc improved from 0.70688 to 0.70716, saving model to Final_Subm_FER_Tony_v1_ensemble_mse.best.hdf5
# Epoch 155/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0235 - acc: 0.8862 - val_loss: 0.0640 - val_acc: 0.7033
#
# Epoch 00155: val_acc did not improve from 0.70716
# Epoch 156/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0235 - acc: 0.8863 - val_loss: 0.0641 - val_acc: 0.7049
#
# Epoch 00156: val_acc did not improve from 0.70716
# Epoch 157/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0235 - acc: 0.8870 - val_loss: 0.0640 - val_acc: 0.7038
#
# Epoch 00157: val_acc did not improve from 0.70716
# Epoch 158/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0235 - acc: 0.8865 - val_loss: 0.0641 - val_acc: 0.7058
#
# Epoch 00158: val_acc did not improve from 0.70716
# Epoch 159/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0235 - acc: 0.8866 - val_loss: 0.0641 - val_acc: 0.7063
#
# Epoch 00159: val_acc did not improve from 0.70716
# Epoch 160/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0235 - acc: 0.8861 - val_loss: 0.0641 - val_acc: 0.7033
#
# Epoch 00160: val_acc did not improve from 0.70716
# Epoch 161/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0235 - acc: 0.8859 - val_loss: 0.0642 - val_acc: 0.7041
#
# Epoch 00161: val_acc did not improve from 0.70716
# Epoch 162/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0235 - acc: 0.8866 - val_loss: 0.0641 - val_acc: 0.7038
#
# Epoch 00162: val_acc did not improve from 0.70716
# Epoch 163/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0235 - acc: 0.8865 - val_loss: 0.0641 - val_acc: 0.7038
#
# Epoch 00163: val_acc did not improve from 0.70716
# Epoch 164/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0235 - acc: 0.8864 - val_loss: 0.0640 - val_acc: 0.7041
#
# Epoch 00164: val_acc did not improve from 0.70716
# Epoch 165/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0235 - acc: 0.8864 - val_loss: 0.0641 - val_acc: 0.7047
#
# Epoch 00165: val_acc did not improve from 0.70716
# Epoch 166/300
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.0235 - acc: 0.8861 - val_loss: 0.0642 - val_acc: 0.7069
#
# Epoch 00166: val_acc did not improve from 0.70716
# Epoch 167/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0235 - acc: 0.8863 - val_loss: 0.0641 - val_acc: 0.7038
#
# Epoch 00167: val_acc did not improve from 0.70716
# Epoch 168/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0235 - acc: 0.8864 - val_loss: 0.0641 - val_acc: 0.7058
#
# Epoch 00168: val_acc did not improve from 0.70716
# Epoch 169/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0235 - acc: 0.8866 - val_loss: 0.0641 - val_acc: 0.7058
#
# Epoch 00169: val_acc did not improve from 0.70716
# Epoch 170/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0235 - acc: 0.8863 - val_loss: 0.0641 - val_acc: 0.7033
#
# Epoch 00170: val_acc did not improve from 0.70716
# Epoch 171/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0234 - acc: 0.8868 - val_loss: 0.0642 - val_acc: 0.7058
#
# Epoch 00171: val_acc did not improve from 0.70716
# Epoch 172/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0235 - acc: 0.8865 - val_loss: 0.0641 - val_acc: 0.7041
#
# Epoch 00172: val_acc did not improve from 0.70716
# Epoch 173/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0235 - acc: 0.8868 - val_loss: 0.0641 - val_acc: 0.7049
#
# Epoch 00173: val_acc did not improve from 0.70716
# Epoch 174/300
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.0234 - acc: 0.8866 - val_loss: 0.0641 - val_acc: 0.7074
#
# Epoch 00174: val_acc improved from 0.70716 to 0.70744, saving model to Final_Subm_FER_Tony_v1_ensemble_mse.best.hdf5
# Epoch 175/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0234 - acc: 0.8866 - val_loss: 0.0642 - val_acc: 0.7066
#
# Epoch 00175: val_acc did not improve from 0.70744
# Epoch 176/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0234 - acc: 0.8862 - val_loss: 0.0641 - val_acc: 0.7033
#
# Epoch 00176: val_acc did not improve from 0.70744
# Epoch 177/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0234 - acc: 0.8871 - val_loss: 0.0642 - val_acc: 0.7080
#
# Epoch 00177: val_acc improved from 0.70744 to 0.70800, saving model to Final_Subm_FER_Tony_v1_ensemble_mse.best.hdf5
# Epoch 178/300
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.0234 - acc: 0.8871 - val_loss: 0.0641 - val_acc: 0.7049
#
# Epoch 00178: val_acc did not improve from 0.70800
# Epoch 179/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0234 - acc: 0.8872 - val_loss: 0.0641 - val_acc: 0.7038
#
# Epoch 00179: val_acc did not improve from 0.70800
# Epoch 180/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0234 - acc: 0.8870 - val_loss: 0.0642 - val_acc: 0.7060
#
# Epoch 00180: val_acc did not improve from 0.70800
# Epoch 181/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0234 - acc: 0.8870 - val_loss: 0.0642 - val_acc: 0.7024
#
# Epoch 00181: val_acc did not improve from 0.70800
# Epoch 182/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0234 - acc: 0.8870 - val_loss: 0.0642 - val_acc: 0.7074
#
# Epoch 00182: val_acc did not improve from 0.70800
# Epoch 183/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0234 - acc: 0.8869 - val_loss: 0.0641 - val_acc: 0.7066
#
# Epoch 00183: val_acc did not improve from 0.70800
# Epoch 184/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0234 - acc: 0.8868 - val_loss: 0.0642 - val_acc: 0.7055
#
# Epoch 00184: val_acc did not improve from 0.70800
# Epoch 185/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0234 - acc: 0.8872 - val_loss: 0.0642 - val_acc: 0.7060
#
# Epoch 00185: val_acc did not improve from 0.70800
# Epoch 186/300
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.0234 - acc: 0.8868 - val_loss: 0.0642 - val_acc: 0.7063
#
# Epoch 00186: val_acc did not improve from 0.70800
# Epoch 187/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0234 - acc: 0.8871 - val_loss: 0.0644 - val_acc: 0.7060
#
# Epoch 00187: val_acc did not improve from 0.70800
# Epoch 188/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0234 - acc: 0.8868 - val_loss: 0.0642 - val_acc: 0.7044
#
# Epoch 00188: val_acc did not improve from 0.70800
# Epoch 189/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0234 - acc: 0.8871 - val_loss: 0.0642 - val_acc: 0.7058
#
# Epoch 00189: val_acc did not improve from 0.70800
# Epoch 190/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0234 - acc: 0.8869 - val_loss: 0.0642 - val_acc: 0.7058
#
# Epoch 00190: val_acc did not improve from 0.70800
# Epoch 191/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0234 - acc: 0.8879 - val_loss: 0.0642 - val_acc: 0.7041
#
# Epoch 00191: val_acc did not improve from 0.70800
# Epoch 192/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0234 - acc: 0.8869 - val_loss: 0.0643 - val_acc: 0.7063
#
# Epoch 00192: val_acc did not improve from 0.70800
# Epoch 193/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0233 - acc: 0.8872 - val_loss: 0.0642 - val_acc: 0.7030
#
# Epoch 00193: val_acc did not improve from 0.70800
# Epoch 194/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0233 - acc: 0.8876 - val_loss: 0.0642 - val_acc: 0.7063
#
# Epoch 00194: val_acc did not improve from 0.70800
# Epoch 195/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0233 - acc: 0.8877 - val_loss: 0.0642 - val_acc: 0.7060
#
# Epoch 00195: val_acc did not improve from 0.70800
# Epoch 196/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0233 - acc: 0.8874 - val_loss: 0.0643 - val_acc: 0.7013
#
# Epoch 00196: val_acc did not improve from 0.70800
# Epoch 197/300
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.0233 - acc: 0.8868 - val_loss: 0.0642 - val_acc: 0.7063
#
# Epoch 00197: val_acc did not improve from 0.70800
# Epoch 198/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0233 - acc: 0.8876 - val_loss: 0.0644 - val_acc: 0.7038
#
# Epoch 00198: val_acc did not improve from 0.70800
# Epoch 199/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0233 - acc: 0.8877 - val_loss: 0.0643 - val_acc: 0.7058
#
# Epoch 00199: val_acc did not improve from 0.70800
# Epoch 200/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0233 - acc: 0.8874 - val_loss: 0.0643 - val_acc: 0.7063
#
# Epoch 00200: val_acc did not improve from 0.70800
# Epoch 201/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0233 - acc: 0.8863 - val_loss: 0.0643 - val_acc: 0.7047
#
# Epoch 00201: val_acc did not improve from 0.70800
# Epoch 202/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0233 - acc: 0.8877 - val_loss: 0.0642 - val_acc: 0.7072
#
# Epoch 00202: val_acc did not improve from 0.70800
# Epoch 203/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0233 - acc: 0.8876 - val_loss: 0.0644 - val_acc: 0.7044
#
# Epoch 00203: val_acc did not improve from 0.70800
# Epoch 204/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0233 - acc: 0.8874 - val_loss: 0.0643 - val_acc: 0.7044
#
# Epoch 00204: val_acc did not improve from 0.70800
# Epoch 205/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0233 - acc: 0.8874 - val_loss: 0.0642 - val_acc: 0.7058
#
# Epoch 00205: val_acc did not improve from 0.70800
# Epoch 206/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0233 - acc: 0.8874 - val_loss: 0.0643 - val_acc: 0.7060
#
# Epoch 00206: val_acc did not improve from 0.70800
# Epoch 207/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0233 - acc: 0.8874 - val_loss: 0.0644 - val_acc: 0.7077
#
# Epoch 00207: val_acc did not improve from 0.70800
# Epoch 208/300
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.0233 - acc: 0.8876 - val_loss: 0.0643 - val_acc: 0.7063
#
# Epoch 00208: val_acc did not improve from 0.70800
# Epoch 209/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0233 - acc: 0.8873 - val_loss: 0.0644 - val_acc: 0.7044
#
# Epoch 00209: val_acc did not improve from 0.70800
# Epoch 210/300
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.0233 - acc: 0.8878 - val_loss: 0.0643 - val_acc: 0.7049
#
# Epoch 00210: val_acc did not improve from 0.70800
# Epoch 211/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0232 - acc: 0.8877 - val_loss: 0.0644 - val_acc: 0.7049
#
# Epoch 00211: val_acc did not improve from 0.70800
# Epoch 212/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0233 - acc: 0.8877 - val_loss: 0.0642 - val_acc: 0.7063
#
# Epoch 00212: val_acc did not improve from 0.70800
# Epoch 213/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0233 - acc: 0.8877 - val_loss: 0.0644 - val_acc: 0.7069
#
# Epoch 00213: val_acc did not improve from 0.70800
# Epoch 214/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0233 - acc: 0.8884 - val_loss: 0.0643 - val_acc: 0.7049
#
# Epoch 00214: val_acc did not improve from 0.70800
# Epoch 215/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0232 - acc: 0.8884 - val_loss: 0.0643 - val_acc: 0.7038
#
# Epoch 00215: val_acc did not improve from 0.70800
# Epoch 216/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0232 - acc: 0.8876 - val_loss: 0.0643 - val_acc: 0.7052
#
# Epoch 00216: val_acc did not improve from 0.70800
# Epoch 217/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0232 - acc: 0.8882 - val_loss: 0.0644 - val_acc: 0.7052
#
# Epoch 00217: val_acc did not improve from 0.70800
# Epoch 218/300
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.0232 - acc: 0.8879 - val_loss: 0.0643 - val_acc: 0.7055
#
# Epoch 00218: val_acc did not improve from 0.70800
# Epoch 219/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0232 - acc: 0.8882 - val_loss: 0.0644 - val_acc: 0.7052
#
# Epoch 00219: val_acc did not improve from 0.70800
# Epoch 220/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0232 - acc: 0.8877 - val_loss: 0.0643 - val_acc: 0.7077
#
# Epoch 00220: val_acc did not improve from 0.70800
# Epoch 221/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0232 - acc: 0.8879 - val_loss: 0.0644 - val_acc: 0.7066
#
# Epoch 00221: val_acc did not improve from 0.70800
# Epoch 222/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0232 - acc: 0.8881 - val_loss: 0.0644 - val_acc: 0.7060
#
# Epoch 00222: val_acc did not improve from 0.70800
# Epoch 223/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0232 - acc: 0.8879 - val_loss: 0.0643 - val_acc: 0.7072
#
# Epoch 00223: val_acc did not improve from 0.70800
# Epoch 224/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0232 - acc: 0.8881 - val_loss: 0.0642 - val_acc: 0.7038
#
# Epoch 00224: val_acc did not improve from 0.70800
# Epoch 225/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0232 - acc: 0.8879 - val_loss: 0.0643 - val_acc: 0.7047
#
# Epoch 00225: val_acc did not improve from 0.70800
# Epoch 226/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0232 - acc: 0.8873 - val_loss: 0.0643 - val_acc: 0.7047
#
# Epoch 00226: val_acc did not improve from 0.70800
# Epoch 227/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0232 - acc: 0.8886 - val_loss: 0.0643 - val_acc: 0.7055
#
# Epoch 00227: val_acc did not improve from 0.70800
# Epoch 228/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0232 - acc: 0.8877 - val_loss: 0.0644 - val_acc: 0.7052
#
# Epoch 00228: val_acc did not improve from 0.70800
# Epoch 229/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0232 - acc: 0.8880 - val_loss: 0.0644 - val_acc: 0.7074
#
# Epoch 00229: val_acc did not improve from 0.70800
# Epoch 230/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0232 - acc: 0.8878 - val_loss: 0.0643 - val_acc: 0.7047
#
# Epoch 00230: val_acc did not improve from 0.70800
# Epoch 231/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0232 - acc: 0.8884 - val_loss: 0.0643 - val_acc: 0.7066
#
# Epoch 00231: val_acc did not improve from 0.70800
# Epoch 232/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0232 - acc: 0.8885 - val_loss: 0.0644 - val_acc: 0.7072
#
# Epoch 00232: val_acc did not improve from 0.70800
# Epoch 233/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0232 - acc: 0.8881 - val_loss: 0.0645 - val_acc: 0.7055
#
# Epoch 00233: val_acc did not improve from 0.70800
# Epoch 234/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0232 - acc: 0.8875 - val_loss: 0.0645 - val_acc: 0.7069
#
# Epoch 00234: val_acc did not improve from 0.70800
# Epoch 235/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0232 - acc: 0.8884 - val_loss: 0.0644 - val_acc: 0.7044
#
# Epoch 00235: val_acc did not improve from 0.70800
# Epoch 236/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0232 - acc: 0.8879 - val_loss: 0.0644 - val_acc: 0.7058
#
# Epoch 00236: val_acc did not improve from 0.70800
# Epoch 237/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0231 - acc: 0.8879 - val_loss: 0.0644 - val_acc: 0.7080
#
# Epoch 00237: val_acc did not improve from 0.70800
# Epoch 238/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0231 - acc: 0.8881 - val_loss: 0.0645 - val_acc: 0.7055
#
# Epoch 00238: val_acc did not improve from 0.70800
# Epoch 239/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0231 - acc: 0.8876 - val_loss: 0.0645 - val_acc: 0.7049
#
# Epoch 00239: val_acc did not improve from 0.70800
# Epoch 240/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0231 - acc: 0.8879 - val_loss: 0.0645 - val_acc: 0.7033
#
# Epoch 00240: val_acc did not improve from 0.70800
# Epoch 241/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0231 - acc: 0.8884 - val_loss: 0.0644 - val_acc: 0.7052
#
# Epoch 00241: val_acc did not improve from 0.70800
# Epoch 242/300
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.0231 - acc: 0.8880 - val_loss: 0.0645 - val_acc: 0.7047
#
# Epoch 00242: val_acc did not improve from 0.70800
# Epoch 243/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0231 - acc: 0.8887 - val_loss: 0.0646 - val_acc: 0.7066
#
# Epoch 00243: val_acc did not improve from 0.70800
# Epoch 244/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0231 - acc: 0.8883 - val_loss: 0.0644 - val_acc: 0.7024
#
# Epoch 00244: val_acc did not improve from 0.70800
# Epoch 245/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0231 - acc: 0.8881 - val_loss: 0.0644 - val_acc: 0.7080
#
# Epoch 00245: val_acc did not improve from 0.70800
# Epoch 246/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0231 - acc: 0.8881 - val_loss: 0.0644 - val_acc: 0.7077
#
# Epoch 00246: val_acc did not improve from 0.70800
# Epoch 247/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0231 - acc: 0.8884 - val_loss: 0.0644 - val_acc: 0.7072
#
# Epoch 00247: val_acc did not improve from 0.70800
# Epoch 248/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0231 - acc: 0.8888 - val_loss: 0.0645 - val_acc: 0.7055
#
# Epoch 00248: val_acc did not improve from 0.70800
# Epoch 249/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0231 - acc: 0.8883 - val_loss: 0.0645 - val_acc: 0.7035
#
# Epoch 00249: val_acc did not improve from 0.70800
# Epoch 250/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0231 - acc: 0.8885 - val_loss: 0.0645 - val_acc: 0.7077
#
# Epoch 00250: val_acc did not improve from 0.70800
# Epoch 251/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0231 - acc: 0.8892 - val_loss: 0.0645 - val_acc: 0.7049
#
# Epoch 00251: val_acc did not improve from 0.70800
# Epoch 252/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0231 - acc: 0.8888 - val_loss: 0.0645 - val_acc: 0.7038
#
# Epoch 00252: val_acc did not improve from 0.70800
# Epoch 253/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0231 - acc: 0.8885 - val_loss: 0.0644 - val_acc: 0.7060
#
# Epoch 00253: val_acc did not improve from 0.70800
# Epoch 254/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0231 - acc: 0.8882 - val_loss: 0.0645 - val_acc: 0.7038
#
# Epoch 00254: val_acc did not improve from 0.70800
# Epoch 255/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0231 - acc: 0.8883 - val_loss: 0.0645 - val_acc: 0.7044
#
# Epoch 00255: val_acc did not improve from 0.70800
# Epoch 256/300
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.0231 - acc: 0.8889 - val_loss: 0.0645 - val_acc: 0.7063
#
# Epoch 00256: val_acc did not improve from 0.70800
# Epoch 257/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0231 - acc: 0.8888 - val_loss: 0.0645 - val_acc: 0.7033
#
# Epoch 00257: val_acc did not improve from 0.70800
# Epoch 258/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0231 - acc: 0.8891 - val_loss: 0.0644 - val_acc: 0.7074
#
# Epoch 00258: val_acc did not improve from 0.70800
# Epoch 259/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0230 - acc: 0.8885 - val_loss: 0.0646 - val_acc: 0.7035
#
# Epoch 00259: val_acc did not improve from 0.70800
# Epoch 260/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0231 - acc: 0.8881 - val_loss: 0.0645 - val_acc: 0.7041
#
# Epoch 00260: val_acc did not improve from 0.70800
# Epoch 261/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0230 - acc: 0.8886 - val_loss: 0.0646 - val_acc: 0.7066
#
# Epoch 00261: val_acc did not improve from 0.70800
# Epoch 262/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0230 - acc: 0.8885 - val_loss: 0.0646 - val_acc: 0.7077
#
# Epoch 00262: val_acc did not improve from 0.70800
# Epoch 263/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0230 - acc: 0.8893 - val_loss: 0.0646 - val_acc: 0.7069
#
# Epoch 00263: val_acc did not improve from 0.70800
# Epoch 264/300
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.0230 - acc: 0.8888 - val_loss: 0.0645 - val_acc: 0.7060
#
# Epoch 00264: val_acc did not improve from 0.70800
# Epoch 265/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0230 - acc: 0.8895 - val_loss: 0.0644 - val_acc: 0.7077
#
# Epoch 00265: val_acc did not improve from 0.70800
# Epoch 266/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0230 - acc: 0.8885 - val_loss: 0.0645 - val_acc: 0.7041
#
# Epoch 00266: val_acc did not improve from 0.70800
# Epoch 267/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0230 - acc: 0.8888 - val_loss: 0.0646 - val_acc: 0.7055
#
# Epoch 00267: val_acc did not improve from 0.70800
# Epoch 268/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0230 - acc: 0.8894 - val_loss: 0.0645 - val_acc: 0.7060
#
# Epoch 00268: val_acc did not improve from 0.70800
# Epoch 269/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0230 - acc: 0.8885 - val_loss: 0.0646 - val_acc: 0.7019
#
# Epoch 00269: val_acc did not improve from 0.70800
# Epoch 270/300
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.0230 - acc: 0.8891 - val_loss: 0.0645 - val_acc: 0.7088
#
# Epoch 00270: val_acc improved from 0.70800 to 0.70883, saving model to Final_Subm_FER_Tony_v1_ensemble_mse.best.hdf5
# Epoch 271/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0230 - acc: 0.8884 - val_loss: 0.0646 - val_acc: 0.7060
#
# Epoch 00271: val_acc did not improve from 0.70883
# Epoch 272/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0230 - acc: 0.8892 - val_loss: 0.0646 - val_acc: 0.7072
#
# Epoch 00272: val_acc did not improve from 0.70883
# Epoch 273/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0230 - acc: 0.8890 - val_loss: 0.0646 - val_acc: 0.7063
#
# Epoch 00273: val_acc did not improve from 0.70883
# Epoch 274/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0230 - acc: 0.8897 - val_loss: 0.0648 - val_acc: 0.7063
#
# Epoch 00274: val_acc did not improve from 0.70883
# Epoch 275/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0230 - acc: 0.8886 - val_loss: 0.0645 - val_acc: 0.7066
#
# Epoch 00275: val_acc did not improve from 0.70883
# Epoch 276/300
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.0230 - acc: 0.8895 - val_loss: 0.0646 - val_acc: 0.7080
#
# Epoch 00276: val_acc did not improve from 0.70883
# Epoch 277/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0230 - acc: 0.8894 - val_loss: 0.0646 - val_acc: 0.7030
#
# Epoch 00277: val_acc did not improve from 0.70883
# Epoch 278/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0230 - acc: 0.8895 - val_loss: 0.0646 - val_acc: 0.7035
#
# Epoch 00278: val_acc did not improve from 0.70883
# Epoch 279/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0229 - acc: 0.8891 - val_loss: 0.0646 - val_acc: 0.7049
#
# Epoch 00279: val_acc did not improve from 0.70883
# Epoch 280/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0230 - acc: 0.8887 - val_loss: 0.0646 - val_acc: 0.7047
#
# Epoch 00280: val_acc did not improve from 0.70883
# Epoch 281/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0229 - acc: 0.8887 - val_loss: 0.0647 - val_acc: 0.7030
#
# Epoch 00281: val_acc did not improve from 0.70883
# Epoch 282/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0230 - acc: 0.8891 - val_loss: 0.0647 - val_acc: 0.7077
#
# Epoch 00282: val_acc did not improve from 0.70883
# Epoch 283/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0230 - acc: 0.8892 - val_loss: 0.0646 - val_acc: 0.7083
#
# Epoch 00283: val_acc did not improve from 0.70883
# Epoch 284/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0229 - acc: 0.8898 - val_loss: 0.0645 - val_acc: 0.7058
#
# Epoch 00284: val_acc did not improve from 0.70883
# Epoch 285/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0229 - acc: 0.8889 - val_loss: 0.0647 - val_acc: 0.7033
#
# Epoch 00285: val_acc did not improve from 0.70883
# Epoch 286/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0229 - acc: 0.8898 - val_loss: 0.0646 - val_acc: 0.7052
#
# Epoch 00286: val_acc did not improve from 0.70883
# Epoch 287/300
# 32181/32181 [==============================] - 1s 42us/step - loss: 0.0229 - acc: 0.8892 - val_loss: 0.0647 - val_acc: 0.7055
#
# Epoch 00287: val_acc did not improve from 0.70883
# Epoch 288/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0229 - acc: 0.8889 - val_loss: 0.0648 - val_acc: 0.7041
#
# Epoch 00288: val_acc did not improve from 0.70883
# Epoch 289/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0229 - acc: 0.8892 - val_loss: 0.0646 - val_acc: 0.7060
#
# Epoch 00289: val_acc did not improve from 0.70883
# Epoch 290/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0229 - acc: 0.8905 - val_loss: 0.0646 - val_acc: 0.7080
#
# Epoch 00290: val_acc did not improve from 0.70883
# Epoch 291/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0229 - acc: 0.8891 - val_loss: 0.0647 - val_acc: 0.7030
#
# Epoch 00291: val_acc did not improve from 0.70883
# Epoch 292/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0229 - acc: 0.8893 - val_loss: 0.0647 - val_acc: 0.7035
#
# Epoch 00292: val_acc did not improve from 0.70883
# Epoch 293/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0229 - acc: 0.8903 - val_loss: 0.0645 - val_acc: 0.7030
#
# Epoch 00293: val_acc did not improve from 0.70883
# Epoch 294/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0229 - acc: 0.8897 - val_loss: 0.0646 - val_acc: 0.7069
#
# Epoch 00294: val_acc did not improve from 0.70883
# Epoch 295/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0229 - acc: 0.8891 - val_loss: 0.0647 - val_acc: 0.7044
#
# Epoch 00295: val_acc did not improve from 0.70883
# Epoch 296/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0229 - acc: 0.8895 - val_loss: 0.0648 - val_acc: 0.7058
# Epoch 00296: val_acc did not improve from 0.70883
# Epoch 297/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0229 - acc: 0.8899 - val_loss: 0.0647 - val_acc: 0.7049
#
# Epoch 00297: val_acc did not improve from 0.70883
# Epoch 298/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0229 - acc: 0.8898 - val_loss: 0.0647 - val_acc: 0.7013
#
# Epoch 00298: val_acc did not improve from 0.70883
# Epoch 299/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0229 - acc: 0.8897 - val_loss: 0.0648 - val_acc: 0.7044
#
# Epoch 00299: val_acc did not improve from 0.70883
# Epoch 300/300
# 32181/32181 [==============================] - 1s 41us/step - loss: 0.0229 - acc: 0.8898 - val_loss: 0.0647 - val_acc: 0.7049
#
# Epoch 00300: val_acc did not improve from 0.70883

# %%
filepath = file_prefix + r"ensemble_mse.best.hdf5"
ensemble_model = load_model(filepath)

# %%
y_pred_ensemble = ensemble_model.predict(x_test_ensemble)

# %%
Y_NN_Ense_pred = []
for row in y_pred_ensemble:
    a = numpy.argmax(np.array(row)) #return the indices of the maximum values along the axis
    Y_NN_Ense_pred.append(a)

# %%
Y_NN_Ense_pred_np = np.array(Y_NN_Ense_pred)
private_set_y_np  = np.array(private_set_y)

# %%
count_correct = np.sum(Y_NN_Ense_pred_np == private_set_y_np)

# %%
len(Y_NN_Ense_pred_np), count_correct
# Out:
# (3589, 2544)

# %%
Y_MSE_Ense_accuracy =(float(count_correct)/len(Y_NN_Ense_pred_np))

# %%
print("Accuracy of Mean Square Error Ensembling on Private Leader Board Data:"+str(Y_MSE_Ense_accuracy))
# Out:
# Accuracy of Mean Square Error Ensembling on Private Leader Board Data:0.7088325438840902

# %% [markdown]
# ### Obeservation
# Using Mean Squared Error(MSE) Loss Ensembling, we could slightly improve the performace of the prediction model from **0.6937** to **0.7088**

# %% [markdown]
# #### Record the performance metrics

# %%
 ModelPerformance.loc[len(ModelPerformance)] = ['MSE Ensembling +  CNN', Y_MSE_Ense_accuracy]

# %% [markdown]
# # 10.  Conclusion

# %% [markdown]
# - Summary of this Conclusion is written on the top in Cell **2 Conclusion**

# %%
#model_performance.plot(kind='bar',title='myplot',legend=model_performance.method_name,loc='best')
ax = ModelPerformance.plot(x= 'method_name', y='accuracy',kind='bar', title ="Accuracy of Different Methods", ylim = (.68, .74), color =['r','g','b','c'], figsize=(8, 6), legend=False, fontsize=14)
ax.set_xlabel("method_name", fontsize=14)
ax.set_ylabel("accuracy", fontsize=14)
plt.show()

# %% [markdown]
# ### Accuracy of different approaches are given below
# 1. Stand-alone **CNN** model: **0.6937**
# 2. Multiple Network Learning Models - **CNN** with Simple Average Ensembling: **0.7015**
# 3. Multiple Network Learning Models - **CNN** with Hinge Loss Ensembling: **0.7068**
# 4. Multiple Network Learning Models - **CNN** with Mean Squred Error(MSE) Ensembling: **0.7088**
# <br/>
# <br/>
# Maximum achieved accuracy of our implementation for **fer2013** dataset:  **0.7088**

# %% [markdown]
# ##  Comparing results
# - Maximum achieved accuracy of our implementation for **fer2013** dataset: **0.7088**
# - We have achieved our objective which was to supass the accuracy of **0.69**
# - Eventhough our implementation was based on **paper [1]** we could not reach the accuracy they have reported (**0.72**)
# - The Kaggle winning method reports an accuracy **0.712**
# - **Paper [4]** has reported an accuracy of f **0.7510** for the Kaggle Challenge

# %% [markdown]
# ## Suggestion to further imporve the accuracy
# - implement **paper [4]**
# - use data augmentation
#     - find data from other sources as well
